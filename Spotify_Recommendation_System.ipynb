# %% [markdown]
# <a href="https://colab.research.google.com/github/RITIK-12/MusicRecommendation/blob/main/Spotify_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Real-time Music Recommendation using PySpark and kafka

# %% [markdown]
# ## Description
#
# In this project, we have created a recommender system that will recommend new musical artists to a user based on their listening history. Suggesting different songs or musical artists to a user is important to many music streaming services, such as Pandora and Spotify.  To create this system you will be using PySpark, Kafka and the collaborative filtering technique. In addition, this type of recommender system could also be used as a means of suggesting TV shows or movies to a user (e.g., Netflix).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 10.5 MB/s
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 30 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 45.1 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=2ceedd14a97d23cf6d7c015bbe261c163b3dce4e6db027cbb80743ee7d2e49b3
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %%
# !pip install findspark
# Out:
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
# !curl -sSOL https://dlcdn.apache.org/kafka/3.1.0/kafka_2.13-3.1.0.tgz
# !tar -xzf kafka_2.13-3.1.0.tgz
# !./kafka_2.13-3.1.0/bin/zookeeper-server-start.sh -daemon ./kafka_2.13-3.1.0/config/zookeeper.properties
# !./kafka_2.13-3.1.0/bin/kafka-server-start.sh -daemon ./kafka_2.13-3.1.0/config/server.properties
# !echo "Waiting for 10 secs until kafka and zookeeper services are up and running"
# !sleep 10
# !ps -ef | grep kafka
# Out:
# Waiting for 10 secs until kafka and zookeeper services are up and running
# root         726       1 19 15:14 ?        00:00:02 java -Xmx512M -Xms512M -server -XX:+UseG1GC -XX:MaxGCPauseMillis=20 -XX:InitiatingHeapOccupancyPercent=35 -XX:+ExplicitGCInvokesConcurrent -XX:MaxInlineLevel=15 -Djava.awt.headless=true -Xlog:gc*:file=/content/kafka_2.13-3.1.0/bin/../logs/zookeeper-gc.log:time,tags:filecount=10,filesize=100M -Dcom.sun.management.jmxremote -Dcom.sun.management.jmxremote.authenticate=false -Dcom.sun.management.jmxremote.ssl=false -Dkafka.logs.dir=/content/kafka_2.13-3.1.0/bin/../logs -Dlog4j.configuration=file:./kafka_2.13-3.1.0/bin/../config/log4j.properties -cp /content/kafka_2.13-3.1.0/bin/../libs/activation-1.1.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/aopalliance-repackaged-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/argparse4j-0.7.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/audience-annotations-0.5.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/commons-cli-1.4.jar:/content/kafka_2.13-3.1.0/bin/../libs/commons-lang3-3.8.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-api-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-basic-auth-extension-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-file-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-json-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-mirror-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-mirror-client-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-runtime-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-transforms-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-api-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-locator-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-utils-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-annotations-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-core-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-databind-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-dataformat-csv-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-datatype-jdk8-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-jaxrs-base-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-jaxrs-json-provider-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-module-jaxb-annotations-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-module-scala_2.13-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.activation-api-1.2.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.annotation-api-1.3.5.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.inject-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.validation-api-2.0.2.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.ws.rs-api-2.1.6.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.xml.bind-api-2.3.2.jar:/content/kafka_2.13-3.1.0/bin/../libs/javassist-3.27.0-GA.jar:/content/kafka_2.13-3.1.0/bin/../libs/javax.servlet-api-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/javax.ws.rs-api-2.1.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jaxb-api-2.3.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-client-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-common-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-container-servlet-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-container-servlet-core-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-hk2-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-server-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-client-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-continuation-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-http-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-io-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-security-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-server-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-servlet-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-servlets-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-util-9 ...
# root        1070       1 67 15:14 ?        00:00:06 java -Xmx1G -Xms1G -server -XX:+UseG1GC -XX:MaxGCPauseMillis=20 -XX:InitiatingHeapOccupancyPercent=35 -XX:+ExplicitGCInvokesConcurrent -XX:MaxInlineLevel=15 -Djava.awt.headless=true -Xlog:gc*:file=/content/kafka_2.13-3.1.0/bin/../logs/kafkaServer-gc.log:time,tags:filecount=10,filesize=100M -Dcom.sun.management.jmxremote -Dcom.sun.management.jmxremote.authenticate=false -Dcom.sun.management.jmxremote.ssl=false -Dkafka.logs.dir=/content/kafka_2.13-3.1.0/bin/../logs -Dlog4j.configuration=file:./kafka_2.13-3.1.0/bin/../config/log4j.properties -cp /content/kafka_2.13-3.1.0/bin/../libs/activation-1.1.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/aopalliance-repackaged-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/argparse4j-0.7.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/audience-annotations-0.5.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/commons-cli-1.4.jar:/content/kafka_2.13-3.1.0/bin/../libs/commons-lang3-3.8.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-api-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-basic-auth-extension-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-file-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-json-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-mirror-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-mirror-client-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-runtime-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/connect-transforms-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-api-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-locator-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/hk2-utils-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-annotations-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-core-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-databind-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-dataformat-csv-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-datatype-jdk8-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-jaxrs-base-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-jaxrs-json-provider-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-module-jaxb-annotations-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jackson-module-scala_2.13-2.12.3.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.activation-api-1.2.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.annotation-api-1.3.5.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.inject-2.6.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.validation-api-2.0.2.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.ws.rs-api-2.1.6.jar:/content/kafka_2.13-3.1.0/bin/../libs/jakarta.xml.bind-api-2.3.2.jar:/content/kafka_2.13-3.1.0/bin/../libs/javassist-3.27.0-GA.jar:/content/kafka_2.13-3.1.0/bin/../libs/javax.servlet-api-3.1.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/javax.ws.rs-api-2.1.1.jar:/content/kafka_2.13-3.1.0/bin/../libs/jaxb-api-2.3.0.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-client-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-common-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-container-servlet-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-container-servlet-core-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-hk2-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jersey-server-2.34.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-client-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-continuation-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-http-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-io-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-security-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-server-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-servlet-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-servlets-9.4.43.v20210629.jar:/content/kafka_2.13-3.1.0/bin/../libs/jetty-util-9.4 ...
# root        1160      71  0 15:15 ?        00:00:00 /bin/bash -c ps -ef | grep kafka
# root        1162    1160  0 15:15 ?        00:00:00 grep kafka

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !wget -q https://www-us.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz

# %%
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz
# Out:
# tar: spark-3.0.1-bin-hadoop2.7.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %% [markdown]
# ## Dataset
#
# We have used some publicly available song data from audioscrobbler for user playlist, which can be found [here](http://www-etud.iro.umontreal.ca/~bergstrj/audioscrobbler_data.html). The original data files are modified so that the code will run in a reasonable time on a single machine. The reduced data files have been suffixed with `_small.txt` and contains only the information relevant to the top 50 most prolific users (highest artist play counts).
#
# The original data file `user_artist_data.txt` contained about 141,000 unique users, and 1.6 million unique artists. About 24.2 million users’ plays of artists are recorded, along with their count.
#
# Note that when plays are scribbled, the client application submits the name of the artist being played. This name could be misspelled or nonstandard, and this may only be detected later. For example, "The Smiths", "Smiths, The", and "the smiths" may appear as distinct artist IDs in the data set, even though they clearly refer to the same artist. So, the data set includes `artist_alias.txt`, which maps artist IDs that are known misspellings or variants to the canonical ID of that artist.
#
# The `artist_data.txt` file then provides a map from the canonical artist ID to the name of the artist.

# %%
import pandas as pd
from kafka import KafkaProducer
from datetime import datetime
import time
import random
import numpy as np

KAFKA_TOPIC_NAME_CONS = "songTopic"
KAFKA_BOOTSTRAP_SERVERS_CONS = '127.0.0.1:9092'

if __name__ == "__main__":
    print("Kafka Producer Application Started ... ")

    kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONS,
                                       value_serializer=lambda x: x.encode('utf-8'))

    filepath = "/content/drive/MyDrive/BigData/tracks.csv"

    songs_df = pd.read_csv(filepath)
    # songs_df = songs_df[songs_df['release_date'] > '2020-01-01']
    songs_df = songs_df[songs_df['popularity'] > 50]

    songs_df['order_id'] = np.arange(len(songs_df))

    songs_df['artists'] = songs_df['artists'].str.replace('[^a-zA-Z]', '')
    songs_df['id_artists'] = songs_df['id_artists'].str.replace('[^a-zA-Z]', '')

    # print(songs_df.head(1))

    song_list = songs_df.to_dict(orient="records")

    message_list = []
    message = None
    print('bj')
    for message in song_list:
        message_fields_value_list = []

        message_fields_value_list.append(message["order_id"])
        message_fields_value_list.append(message["id"])
        message_fields_value_list.append(message["name"])
        message_fields_value_list.append(message["popularity"])
        message_fields_value_list.append(message["duration_ms"])
        message_fields_value_list.append(message["explicit"])
        message_fields_value_list.append(message["artists"])
        message_fields_value_list.append(message["id_artists"])
        message_fields_value_list.append(message["release_date"])
        message_fields_value_list.append(message["danceability"])
        message_fields_value_list.append(message["energy"])
        message_fields_value_list.append(message["key"])
        message_fields_value_list.append(message["loudness"])
        message_fields_value_list.append(message["mode"])
        message_fields_value_list.append(message["speechiness"])
        message_fields_value_list.append(message["acousticness"])
        message_fields_value_list.append(message["instrumentalness"])
        message_fields_value_list.append(message["liveness"])
        message_fields_value_list.append(message["valence"])
        message_fields_value_list.append(message["tempo"])
        message_fields_value_list.append(message["time_signature"])

        message = ','.join(str(v) for v in message_fields_value_list)
        print('ghgjhh')
        print("Message Type: ", type(message))
        print("Message: ", message)
        kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
        time.sleep(1)

    print("Kafka Producer Application Completed. ")
# Out:
# Kafka Producer Application Started ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: FutureWarning: The default value of regex will change from True to False in a future version.
# Streaming output truncated to the last 5000 lines.
# Message Type:  <class 'str'>
# Message:  5082,765k9tDIFOnoOfkO2cgitB,Take Me with U,52,234133,0,Prince,aEaRhamoenGrDuVnj,1984-06-25,0.707,0.814,2,-10.677,1,0.0288,0.0859,0.00281,0.234,0.697,121.92,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5083,6zsV35nw0bwltn6z1CSSOa,La Mal Sentada,52,204324,0,AntonioAguilar,PNfbeKbuzlRYnoajNm,1984-01-01,0.806,0.338,0,-10.967,1,0.108,0.635,6.4e-05,0.589,0.694,114.255,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5084,10nE6yd1TUUtjpuLeapZmN,ワインレッドの心,52,250507,0,AnzenChitai,EAqVJtaxnPcWYlHXkHcuC,1984,0.716,0.47,6,-12.056,0,0.0277,0.0458,1.16e-05,0.197,0.662,118.824,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5085,3QwDN08fGnGfRrsn5wLTej,Cold Shot,52,240987,0,StevieRayVaughan,fsDcuclIeZiBDPK,1984,0.427,0.553,6,-11.434,0,0.0405,0.344,0.000956,0.227,0.674,109.629,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5086,0UkVtmw0ZzEd9vzAa7Ocnu,Love Never Felt So Good,52,259560,0,JohnnyMathis,LGsWbziRLedxWZWf,1984-01-22,0.824,0.714,4,-8.362,0,0.0489,0.253,0.0293,0.342,0.825,114.998,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5087,7wxV4cgdjz0rRXujlUIyZJ,Going Home - Live At Hammersmith Odeon, London/1983,52,365493,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1984-03-14,0.314,0.328,7,-10.932,1,0.0443,0.257,0.0565,0.645,0.116,119.698,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5088,5UFBEYaigXPoScwPOK4Wft,Be My Number Two,51,259693,0,JoeJackson,KOqPxwfNAmZPkiCnDEyT,1984-01-01,0.397,0.312,7,-10.096,1,0.0305,0.336,0.0,0.367,0.283,110.183,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5089,4LY4j1ziOoVQm8beWBRYVN,Déjame Vivir (with Juan Gabriel),51,223573,0,RocoDrcalJuanGabriel,uyweLamvPZHeRzDddeBMRBDrcrHWEJwPceFncq,1984-04-26,0.753,0.26,7,-15.042,1,0.0505,0.66,0.0,0.0929,0.76,131.702,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5090,19PzodASoRXuOYKZbIPcN8,Cadillac Ranch,51,222773,0,NittyGrittyDirtBand,ydchJuuuNnwlsOQvwW,1984,0.65,0.724,4,-7.252,1,0.0286,0.00902,4.1e-05,0.319,0.886,134.816,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5091,37Q1Ql8jgueqnmN0D4sFEb,What Is Love? - Extended Mix,51,396093,0,HowardJones,loBFiQdEWSXfNKqY,1984,0.631,0.74,0,-10.22,0,0.0452,0.303,0.00132,0.136,0.91,97.0,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5092,2n3ERDAyw57jX3iLZfADse,Fürstenfeld,51,323200,0,STS,nwKjjorZtErRVgzOPB,1984-01-01,0.63,0.679,7,-14.168,1,0.115,0.153,5.9e-06,0.0405,0.657,117.645,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5093,11kmPqb02yGcZtLilUoHMd,Marvin - Ao vivo,51,237107,0,Tits,euXvCVnJyTVEGfcRCl,1984-05-30,0.708,0.832,11,-3.652,1,0.212,0.382,0.0,0.334,0.806,176.349,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5094,6CMzq5lR2EFeq3ENPNG18L,Hoy Voy a Tomar,51,247413,0,AlfredoLinaresClaudioMoran,cQFJQUMfKbGBygFYCdnhmhYTyOadrWzOtAO,1984-07-31,0.613,0.779,11,-8.818,0,0.0353,0.536,0.00368,0.296,0.949,97.115,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5095,3b0rbuHtD50p1gmfYeKCom,Cherry Pie,51,378733,0,Sade,zzsobNUcODyBTDvKx,1984-07-16,0.693,0.758,5,-9.758,1,0.0369,0.378,0.00837,0.13,0.798,97.345,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5096,3axPhcbhVDOA9MnhkUrFcE,Boogie Woogie Bugle Boy,51,161933,0,TheAndrewsSisters,NCGIdLTxLdIXHdvQfM,1984-01-01,0.64,0.479,7,-11.55,1,0.467,0.881,0.000171,0.0973,0.79,166.868,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5097,4EVFCcP3BtujqYgw9jV3yF,Me Va, Me Va,51,363827,0,JulioIglesias,etuCZVdPyiNPnxfie,1984,0.677,0.633,2,-16.023,1,0.0526,0.259,0.00728,0.137,0.625,99.705,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5098,3uXVAyaaYadFSbbj1SQBK4,Elle a les yeux revolver,51,216800,0,MarcLavoine,KEYZLtgythgGZzrFXf,1984,0.567,0.379,5,-11.236,1,0.0566,0.493,9.45e-05,0.1,0.5,79.958,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5099,29XaS3POtNrgCl8sewWM0v,Payaso,51,178600,0,JosJos,mNqcMxWXoToqfDPMyV,1984-05-23,0.571,0.523,9,-9.173,1,0.0337,0.315,0.000531,0.531,0.481,99.869,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5100,1Cg8HzQLJ4rjjXprgotjJj,Crazy,51,223667,0,KennyRogers,twLmntTPUvGymVPI,1984-08-27,0.454,0.186,1,-16.281,1,0.031,0.727,5.49e-06,0.0783,0.303,136.173,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5101,35kvOewUqIxHMf8Djyk4IC,Cocaine Carolina,51,166960,0,DavidAllanCoe,nwhAhPpbwOUnHZJWrHT,1984-04-01,0.597,0.44,7,-10.465,1,0.0382,0.383,0.0,0.07,0.952,90.351,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5102,2bsczk82MWGPmTbe6IWYsa,Moments In Love,51,615693,0,TheArtOfNoise,zrvBORXcnTyysjjKRfBU,1984-06-19,0.696,0.234,9,-14.991,1,0.112,0.28,0.0511,0.311,0.489,138.118,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5103,0oX26umaR6eROaFRzmkTRG,Çocuklar Gibi,51,256030,0,SezenAksu,drUxfizSAOEUbMnUZd,1984-09-06,0.409,0.302,9,-8.15,0,0.0293,0.685,0.0,0.0903,0.352,106.96,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5104,2odo6Lq6sOadOslMxzkGMw,Cielo Azul, Cielo Nublado,51,138440,0,CarlosYJose,IRfUbSEqoOzedNHXVDXb,1984-01-01,0.752,0.461,7,-6.35,1,0.0315,0.419,0.000103,0.0406,0.96,109.496,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5105,2JD91cpdSGoNh9K50GmByg,Por Qué No Puedo Ser Del Jet Set? - Remasterizado 2007,51,140347,0,SodaStereo,AnyvFhDYDolNmzKBp,1984-02-06,0.63,0.973,7,-3.356,1,0.135,0.0974,0.391,0.288,0.968,178.183,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5106,6NG0ZuJsu99WgQ2yFUUAOy,The More You Live, The More You Love,51,250520,0,AFlockOfSeagulls,uAjBatvBubpdkCfjmNt,1984,0.622,0.74,11,-10.271,0,0.0354,0.00388,0.00405,0.538,0.786,139.525,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5107,1YhyOTcVjHe73cm6tYrHkA,Middle of the Road - 2007 Remaster,51,254293,0,Pretenders,GByyDcfbQwDvXGCWmzv,1984,0.488,0.959,9,-5.575,1,0.0758,0.00333,0.0767,0.025,0.67,166.799,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5108,0wW9b7PRLE7JruS2QOdq92,Amores Fingidos,51,177907,0,CarlosYJose,IRfUbSEqoOzedNHXVDXb,1984-01-01,0.647,0.44,9,-5.115,1,0.0327,0.386,5.47e-05,0.067,0.697,114.543,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5109,4DzZEBT0eX8oOmELwoHo72,Mr Clicketty Cane (Wash Your Face in Orange Juice),51,151933,0,PeterCombe,UrDIpvxUUaSgkaSkcpjb,1984,0.749,0.734,2,-12.658,1,0.0436,0.299,0.0,0.289,0.922,135.868,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5110,1qv9TWDpXh50DPLgWD4bnH,Happy Ending,51,218467,0,JoeJacksonElaineCaswell,KOqPxwfNAmZPkiCnDEyTuHHQBgVrLPiiWmDD,1984-01-01,0.635,0.808,9,-5.026,1,0.0262,0.0973,0.0,0.141,0.726,131.377,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5111,5vrMM7hAZPQx9955euW6Jb,Blue Jean - 2018 Remaster,51,191907,0,DavidBowie,oSGxfWSnnOXhDfKuzGy,1984-09-29,0.559,0.849,2,-6.39,1,0.0308,0.0401,0.33,0.131,0.822,124.608,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5112,1y9yrdjt1wjKlD2UHrnUVj,El Perro Negro,51,156960,0,JosAlfredoJimenez,TwhbsUiufLjQtz,1984,0.738,0.203,0,-16.441,1,0.0621,0.952,4.16e-06,0.13,0.889,95.298,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5113,53MYtv4tzLYg1hbu13Qbc0,Albachiara,51,245533,0,VascoRossi,lnhyzRhgEdh,1984-01-15,0.404,0.718,0,-8.145,1,0.0669,0.51,3.99e-06,0.0361,0.449,145.315,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5114,7z8k6KAvjHX3RtkYNhIC9B,Magic,51,237093,0,TheCars,DCIjjNaNpBzeoKFPtp,1984-03-13,0.683,0.806,9,-7.574,1,0.042,0.125,0.000548,0.191,0.962,118.032,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5115,0NFYBiY95SUauRVdgf77PK,Handsome Devil - John Peel Session 18/05/83,51,164560,0,TheSmiths,yYgUcIsjMrhjoPoJ,1984,0.325,0.921,11,-6.774,0,0.0519,7.44e-06,0.0323,0.246,0.747,197.655,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5116,4rrbptVnZifk4wC5mvNDPm,My War,51,226333,0,BlackFlag,MhsEulUsRCtRYsmABV,1984-03-01,0.215,0.503,1,-16.318,0,0.0463,0.65,0.0283,0.098,0.35,186.866,1
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5117,5DYD5pUUnf3MT6LafqPqOt,When Am I Going to Make a Living,51,205973,0,Sade,zzsobNUcODyBTDvKx,1984-07-16,0.693,0.652,9,-6.524,1,0.0288,0.471,0.0,0.0922,0.83,94.324,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5118,5562EZVkcwO43I03C29RuK,Este Ritmo Se Baila Así,51,268427,0,Chayanne,JbemQfPtYmSLjAFhPBv,1984-01-10,0.765,0.577,10,-15.334,0,0.103,0.091,0.0539,0.0711,0.85,133.766,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5119,6L3rEi9FdKAuwCz1DiWkIk,Cómo pudiste hacerme esto a mí,51,247067,0,AlaskaYDinarama,mDlFcPtgXtLFgEshEInh,1984-05-29,0.599,0.906,0,-3.009,1,0.0412,0.0455,4.91e-06,0.0375,0.392,140.264,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5120,3oDtHLkS4k687WbPCd7EdN,I Feel Love,51,361827,0,BronskiBeat,wpWOzQETpAdVnhYD,1984-10-15,0.623,0.724,9,-11.598,0,0.0266,0.326,0.0115,0.573,0.857,139.538,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5121,2cD3pqgT9Yn4GUcGflMYdk,Love Is Alive,51,238507,0,TheJudds,MSTObsbDOJQTxLsIc,1984-10-15,0.698,0.381,4,-11.281,1,0.0291,0.233,8.51e-06,0.106,0.365,86.302,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5122,0DVC2pMTkDmkoAW3XyIdYe,Envole-moi,51,306120,0,JeanJacquesGoldman,CxOTMqagpzlcGG,1984-01-01,0.595,0.818,4,-3.115,0,0.0555,0.153,0.0,0.0878,0.411,112.686,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5123,4pRms8DFBAvUrdxZxnh7xL,Liebe ohne Leiden,51,222000,0,UdoJrgensJenny,GhtBPxlOonxnIismurEqNvgRReKkOVYzeeUScz,1984-09-21,0.591,0.567,4,-12.229,0,0.0312,0.381,0.0,0.0507,0.704,126.388,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5124,5aqLXmh8SpcmR21finoww3,Fotoromanza,51,267840,0,GiannaNannini,hpRkMjCUMdcfnXmHjX,1984-11-27,0.458,0.66,11,-13.018,1,0.0456,0.154,4.45e-05,0.381,0.959,170.319,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5125,2LAgzgp3kmBG6uOqwms3eR,Sad Songs (Say So Much),51,295533,0,EltonJohn,PhoLpVuITZKcymswpckb,1984-07-09,0.761,0.742,0,-11.207,1,0.025,0.0898,0.000951,0.0512,0.94,107.395,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5126,1OkNX7XwRwzfWE7Oqp8Rri,Flugzeuge im Bauch - Remastered 2016,51,233720,0,HerbertGrnemeyer,tGdlmSwBwYBpsyg,1984-08-14,0.461,0.291,0,-9.749,1,0.031,0.868,0.0102,0.0785,0.23,139.543,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5127,0Lcycsddsg3T9F9sqDTWgx,Vamos fugir (Participação especial de The Wailers),51,289413,0,GilbertoGilTheWailers,oEkUINVIjNrWnjtzqrwNMEbGEQNwMJabSPM,1984,0.732,0.528,6,-9.83,0,0.108,0.487,0.0177,0.0411,0.91,134.751,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5128,630zE7N1xPxdK2Zz4S3rPA,Piano Sonata No.14 In C Sharp Minor, Op.27 No.2 -"Moonlight": 1. Adagio sostenuto,51,403333,0,LudwigvanBeethovenDanielBarenboim,wOqMjpTyABvtHdOSOTUSsEozQOEJxzXegUuqRSgH,1984-01-01,0.278,0.00245,1,-41.53,0,0.0497,0.995,0.881,0.114,0.293,139.161,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5129,0MXpsn1TiYioFpB0CJ7PDX,Robert De Niro's Waiting,51,222189,0,Bananarama,sciUGWwpwxbHeZolgx,1984-01-01,0.686,0.806,7,-5.46,1,0.0272,0.0424,0.00027,0.296,0.833,130.321,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5130,1grnSNpTAe14gjtqfArZan,New Girl Now,51,216693,0,HoneymoonSuite,kFyhQTVcbdiSYWytQ,1984-06-14,0.589,0.768,9,-11.493,1,0.0417,0.104,0.0,0.0897,0.694,109.127,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5131,2IAQnOWKWjj1iA166KznVd,Never Ending Story,51,210013,0,Limahl,LTzUnZaptYfAFmvqWMD,1984,0.579,0.803,0,-7.588,1,0.0281,0.22,0.00116,0.22,0.77,122.422,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5132,0AkmNg3BN8xBuECm5xllwR,Nunca Quedas Mal Con Nadie,51,250984,0,LosPrisioneros,mSHYJORnRimtHqVa,1984,0.566,0.932,2,-6.848,1,0.0693,0.307,0.0,0.342,0.902,155.063,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5133,7KgneETGBycWbmIfK2fagH,Curious,51,306453,0,MidnightStar,KMLfCXYbDhfhLpucVd,1984-01-01,0.79,0.487,7,-9.881,1,0.0532,0.0174,0.000441,0.333,0.464,100.67,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5134,2WfaOiMkCvy7F5fcp2zZ8L,Take on Me,86,225280,0,aha,jzcTCTVFLXQlBNiIUzE,1985-06-01,0.573,0.902,6,-7.638,0,0.054,0.018,0.00125,0.0928,0.876,84.412,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5135,4RvWPyQ5RL0ao9LPZeSouE,Everybody Wants To Rule The World,84,251489,0,TearsForFears,bthkUfsYUYdcFyqxmSUU,1985-02-25,0.645,0.795,7,-12.095,1,0.0527,0.347,0.00389,0.104,0.535,112.067,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5136,1ko2lVN0vKGUl9zrU0qSlT,Just the Two of Us (feat. Bill Withers),82,237106,0,GroverWashingtonJrBillWithers,YVYeVHxYprrWalvuEThoqLcyIYvZniWbjfsj,1985,0.802,0.488,1,-9.304,1,0.0813,0.572,0.0598,0.0763,0.624,95.77,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5137,05wIrZSwuaVWhcv5FfqeH0,Walking On Sunshine,79,238733,0,KatrinaTheWaves,TzHIUhVpeeDxyJPpQfnV,1985,0.596,0.869,10,-11.97,1,0.037,0.0116,0.173,0.0678,0.944,109.902,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5138,3Ud6fFep5ZlXzRWw6Sm8no,Walk Of Life,78,249960,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.462,0.918,4,-8.507,1,0.0959,0.405,0.00033,0.126,0.802,172.427,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5139,6OnfBiiSc9RGKiBKKtZXgQ,We Built This City,78,296080,0,Starship,kObWapDEgEAJPBxzf,1985-09-10,0.661,0.908,5,-4.897,1,0.039,0.052,0.0,0.0708,0.656,144.091,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5140,2KH16WveTQWT6KOG9Rg6e2,Eye of the Tiger,77,245640,0,Survivor,bcqnyjGBuRriQg,1985,0.817,0.599,0,-9.249,0,0.0328,0.132,0.000311,0.0873,0.548,108.873,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5141,3fH4KjXFYMmljxrcGrbPj9,Don't You (Forget About Me),76,263040,0,SimpleMinds,hNFiuULZYWXppobAj,1985,0.66,0.816,2,-6.61,1,0.0299,0.168,0.0181,0.0608,0.678,111.346,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5142,1Wrzhfa5bNlqvsnCztz190,Devuélveme a mi chica,76,194867,0,HombresG,uhKYYSCqAgJNxcUDA,1985,0.603,0.843,9,-7.597,0,0.0557,0.0031,0.0337,0.445,0.503,172.676,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5143,31DvHUCSioX0JD7B4kZMJ9,Money For Nothing,75,510933,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.666,0.667,2,-9.305,0,0.0371,0.043,0.0005,0.074,0.679,134.219,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5144,4oDZ5L8izBals6jKBJDBcX,Your Love,74,216467,0,TheOutfield,zxDewzdjZdSBGaYcry,1985-06-29,0.579,0.654,1,-12.421,0,0.0553,0.121,3.62e-06,0.0673,0.616,129.537,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5145,0CzeAbfKFnxnWjwo5iYiCG,Brothers In Arms,73,424000,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.413,0.296,8,-13.904,0,0.0277,0.531,0.801,0.183,0.144,79.273,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5146,5tdKaKLnC4SgtDZ6RlWeal,How Will I Know,73,275533,0,WhitneyHouston,XpaIBNiVzIetEPCWDvAFP,1985-02-14,0.832,0.544,6,-12.697,1,0.0442,0.201,0.000139,0.632,0.928,119.49,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5147,6tu2FHuKL9C8pwNrityweQ,Te quiero,73,225760,0,HombresG,uhKYYSCqAgJNxcUDA,1985-01-01,0.736,0.711,2,-5.503,1,0.0352,0.0029,0.000275,0.0948,0.72,112.305,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5148,5dRQUolXAVX3BbCiIxmSsf,Your Love,72,221840,0,TheOutfield,zxDewzdjZdSBGaYcry,1985,0.555,0.757,1,-7.868,0,0.0601,0.103,1.16e-06,0.0631,0.582,129.607,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5149,2gQaQUhDCNGfBVXTvxAmXQ,Shout,72,393667,0,TearsForFears,bthkUfsYUYdcFyqxmSUU,1985-02-25,0.511,0.942,0,-10.407,1,0.0429,0.174,1.87e-05,0.139,0.498,97.909,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5150,78FHUZRbFDCG6VkRAQdFLm,Broken Wings,71,343933,0,MrMister,BahEkCETqEpAHICPzQ,1985-11-27,0.286,0.5,1,-14.281,0,0.0357,0.134,4.57e-05,0.108,0.443,99.162,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5151,3uMYq07Kj5m564OQwdSCrD,Cuando Pase El Temblor - Remasterizado 2007,70,229160,0,SodaStereo,AnyvFhDYDolNmzKBp,1985-10-09,0.652,0.607,0,-8.657,1,0.0368,0.0314,0.00285,0.0721,0.72,94.089,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5152,4zXvB4MoQD8onk0NCZbeHG,Home Sweet Home,70,240933,0,MtleyCre,ccvwVNYlIcvrvtBL,1985,0.403,0.777,5,-6.416,1,0.0354,0.0999,3.28e-06,0.124,0.149,76.329,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5153,7jWbXvrgdbkajU8L28ahn5,Highwayman,70,182653,0,TheHighwaymenWillieNelsonJohnnyCashWaylonJenningsKrisKristofferson,eQpHYqEiyJGiMIysLaWbDNCqJjbCgTxDDCbkACVPfCOnqzgfEFrylxwCjDgVnqBsHguQXPAaIMvYQRWLIDeYQOccTviQNX,1985-05-01,0.67,0.351,2,-16.842,1,0.0463,0.48,0.0176,0.115,0.45,101.384,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5154,6fkvIT9KFKxO8poBeKfaEf,One More Night - 2016 Remaster,70,288973,0,PhilCollins,lxfqrEsLXNNOCSkILp,1985-01-25,0.534,0.442,3,-9.442,1,0.0308,0.788,0.000351,0.0986,0.343,136.369,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5155,3qLZ866ZfaK0B0R5FIqXLG,She Sells Sanctuary,70,252533,0,TheCult,DWKvkyjHOmKJnSyS,1985-10-18,0.55,0.765,7,-8.684,1,0.0287,4.76e-06,0.873,0.132,0.419,139.46,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5156,1BY1Vd2Bt6JPOhMvsIwtVv,Dancing With Myself,70,359733,0,BillyIdol,lzordPuZEXxwtaoVZYmG,1985,0.51,0.696,4,-10.83,1,0.0802,0.0157,0.000104,0.297,0.905,176.568,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5157,1yg7fwwYmx9DQ2TdXUmfpJ,Holding Back the Years - 2008 Remaster,70,269840,0,SimplyRed,facOhromAZdqxRAvv,1985,0.707,0.514,9,-8.885,0,0.0281,0.58,0.000159,0.0953,0.524,86.035,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5158,0vB4Vd6PtkJSEnWsmqATnZ,Nothing's Gonna Change My Love for You,70,242679,0,GeorgeBenson,NBwYTECXqykGvXXlmfv,1985-01-15,0.553,0.614,1,-5.098,1,0.0306,0.764,0.0,0.0811,0.345,136.628,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5159,5izGeTxueiFX1UPFGohY9w,Addicted To Love,70,363640,0,RobertPalmerEricETThorngren,SdmeqqzWBdDmILMgnutOKaRyZACdXJYTIX,1985-01-01,0.702,0.578,2,-13.415,1,0.031,0.382,5.89e-06,0.0425,0.975,111.617,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5160,273uCXd7NPrInaiNqtkOrA,Tarzan Boy,69,378947,0,Baltimora,czfQMjHVmvJKALAnviG,1985-01-01,0.684,0.573,5,-12.3,1,0.0261,0.318,0.028,0.306,0.716,107.363,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5161,4xiyq1iRdsxuU1BPUJ490Z,Close To Me,69,203267,0,TheCure,buHJOdUbMoVzbos,1985-08-26,0.724,0.523,11,-11.139,1,0.116,0.0745,0.703,0.0811,0.965,185.075,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5162,3G0ENKW9vzV0SuYKaWFflI,Nikita,69,343240,0,EltonJohn,PhoLpVuITZKcymswpckb,1985-11-07,0.632,0.656,7,-9.29,1,0.0277,0.123,0.000264,0.0735,0.752,86.605,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5163,2aEuA8PSqLa17Y4hKPj5rr,Cheri Cheri Lady,69,226333,0,ModernTalking,bxUQsBIXOnVLBfYKf,1985,0.677,0.616,10,-13.826,1,0.032,0.458,0.0132,0.349,0.851,114.223,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5164,7INi4pMPG4IE0Smx5y4KVf,Easy Lover,69,304507,0,PhilipBaileyPhilCollins,ZNeppgfBLPUyugksYnulxfqrEsLXNNOCSkILp,1985-03-20,0.749,0.699,1,-13.108,1,0.0371,0.0674,0.00192,0.0763,0.935,128.904,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5165,0Dm43YLUlGdePpSbI1ct8h,Part-Time Lover,69,252560,0,StevieWonder,guDJrEfXqbFEbdPAqi,1985-09-13,0.662,0.624,10,-13.606,0,0.0417,0.165,0.0,0.0674,0.961,174.513,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5166,3Z2tPWiNiIpg8UMMoowHIk,We Are The World,69,427333,0,USAForAfrica,sFmPpWGmJgzzmzM,1985-01-01,0.528,0.447,4,-15.255,1,0.0435,0.189,0.0,0.0745,0.292,72.58,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5167,6yJxCltgtmGxIgKOS6ndnu,Greatest Love of All,68,291400,0,WhitneyHouston,XpaIBNiVzIetEPCWDvAFP,1985-02-14,0.502,0.305,9,-16.011,1,0.0339,0.484,3.55e-06,0.117,0.248,131.242,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5168,1A2PWRltFrX8iB8IP3CUgo,St. Elmos Fire (Man in Motion),68,251800,0,JohnParr,ZtibPKhUYWCnoIYicCN,1985-01-01,0.612,0.6,9,-10.945,1,0.0327,0.15,3.04e-06,0.222,0.471,111.203,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5169,1c9dnQbOzw01ID7X2IsYOE,Slave To Love,68,266333,0,BryanFerry,RNFFojXkPRmlJZIwXeKQC,1985,0.661,0.818,2,-5.9,1,0.0291,0.182,0.000995,0.0527,0.79,147.544,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5170,15mZo1Kah03g8CTLbSsWrr,The Whole of the Moon - 2004 Remaster,68,302827,0,TheWaterboys,TnuPpwUrjjeabtwZ,1985-09-16,0.606,0.794,0,-7.168,1,0.0291,0.119,7.16e-06,0.125,0.584,105.813,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5171,4qM461TqtpnP4GLRIXwEnW,Sussudio - 2016 Remaster,68,263107,0,PhilCollins,lxfqrEsLXNNOCSkILp,1985-01-25,0.714,0.935,5,-5.195,1,0.0849,0.0529,0.0934,0.0515,0.725,121.232,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5172,5jSz894ljfWE0IcHBSM39i,Raspberry Beret,67,215173,0,Prince,aEaRhamoenGrDuVnj,1985-04-22,0.761,0.67,2,-12.759,1,0.0438,0.21,0.000426,0.0685,0.91,120.752,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5173,2x5IXUFOcvvBUtEpnCBNlp,Alive And Kicking,67,289453,0,SimpleMinds,hNFiuULZYWXppobAj,1985,0.572,0.913,0,-4.26,1,0.0362,0.0753,1.5e-05,0.128,0.561,103.265,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5174,75FEaRjZTKLhTrFGsfMUXR,Running Up That Hill (A Deal With God),67,298933,0,KateBush,aSxMhuvixZhdKjIDwL,1985,0.629,0.547,10,-13.123,0,0.055,0.72,0.00314,0.0604,0.197,108.375,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5175,2HsjJJL4DhPCzMlnaGv7ap,Small Town,67,221627,0,JohnMellencamp,lPQFkJOwGWAFORFCqH,1985,0.659,0.919,11,-2.658,1,0.0333,0.155,0.0054,0.312,0.631,123.135,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5176,2PkTjm1QAJCZbJ9MqC4RqA,11 Y 6,67,178267,0,FitoPaez,bZNvqOxYqmmnLhaTu,1985-01-01,0.72,0.325,7,-16.922,1,0.0319,0.0756,0.0,0.308,0.318,101.3,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5177,1OzrlK57iLTIjmbZC1ppWM,That's What Friends Are For (with Elton John, Gladys Knight & Stevie Wonder),67,255933,0,DionneWarwickEltonJohnGladysKnightStevieWonder,JSjCHKgdaiPWdKiNUNpPhoLpVuITZKcymswpckbaXiJJHJeiBmCykxIyguDJrEfXqbFEbdPAqi,1985,0.68,0.242,0,-16.264,0,0.0322,0.509,4.34e-05,0.071,0.169,120.126,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5178,5sf1wqBZsHkpy7dPnDb7aD,All the Love in the World,66,212240,0,TheOutfield,zxDewzdjZdSBGaYcry,1985-06-29,0.624,0.531,4,-13.23,1,0.0408,0.0403,1.21e-06,0.0914,0.743,128.08,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5179,0Zn63G0XTiqXwr1KSmARWz,You're My Heart, You're My Soul,66,334600,0,ModernTalking,bxUQsBIXOnVLBfYKf,1985,0.845,0.541,1,-9.029,0,0.0748,0.0586,0.0586,0.149,0.79,117.362,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5180,07itbZUgkAmBi4CEH5NniJ,I Got You Babe,66,189093,0,UBChrissieHynde,MEOAADKgIZrqXLzoozLlEZTdSVpjHgWwZMsi,1985-01-01,0.756,0.61,5,-13.002,1,0.0709,0.0806,7.89e-05,0.114,0.863,173.818,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5181,1lx8ddGT5wCD6W2xmLeRKG,Saving All My Love for You,66,238467,0,WhitneyHouston,XpaIBNiVzIetEPCWDvAFP,1985-02-14,0.636,0.264,6,-14.567,0,0.0263,0.593,4.22e-05,0.275,0.264,99.304,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5182,5lwQGZYF4BXOzFtXc5zk8q,Head Over Heels - Dave Bascombe 7" N.Mix,66,257316,0,TearsForFearsDaveBascombe,bthkUfsYUYdcFyqxmSUUpAVaThptdebneOqDfYI,1985-02-25,0.623,0.739,7,-8.116,1,0.0244,0.338,1.88e-05,0.109,0.642,95.007,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5183,7cR56TtuWIktf7jaZfyIgz,Your Latest Trick,66,393267,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.703,0.409,4,-13.491,1,0.0339,0.719,0.0996,0.0697,0.252,122.56,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5184,3QHThjKGMW7y89xIEvB0J4,So Far Away - Full Version,66,308800,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.698,0.473,4,-11.741,1,0.0283,0.244,0.211,0.063,0.694,114.453,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5185,7hkQhMFq4EOTYwX3I7cgmA,Será,66,150467,0,LegioUrbana,twEpCRgmSRZiZgnt,1985-01-01,0.281,0.866,0,-10.628,1,0.0647,0.122,0.00355,0.324,0.42,193.928,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5186,5yGTQzYbEdY6B9RFZJypgt,Rhythm Of The Night,65,229107,0,DeBarge,isUIjlIPjxNZOHIMV,1985,0.707,0.759,11,-12.328,0,0.046,0.0769,2.84e-05,0.0775,0.955,115.142,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5187,4CRpOsjhvgxjF7rQufmyZ1,Inbetween Days,65,177987,0,TheCure,buHJOdUbMoVzbos,1985-08-26,0.546,0.836,9,-6.321,1,0.0317,0.107,0.583,0.166,0.735,142.605,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5188,3M7WBL64QOmuPiPjhySCJW,Sergio el Bailador,65,169600,0,Bronco,VKhCQDiMkUvaBMoKV,1985,0.789,0.67,7,-12.263,1,0.0578,0.306,0.0,0.0435,0.984,89.532,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5189,5bnMKUXkMfYVXW8FjvFTuV,No Easy Way Out - From "Rocky IV" Soundtrack,65,262027,0,RobertTepper,TbhiyEDhokaKTechcKI,1985,0.543,0.829,4,-7.916,0,0.0497,0.00146,4.91e-05,0.289,0.64,126.195,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5190,1LwP9g1Hjbs64jXM2Qsxry,Just Like Honey,65,182493,0,TheJesusandMaryChain,rjlerNygkIhmUvirs,1985-11-18,0.341,0.552,8,-10.503,1,0.0423,8.02e-05,0.616,0.0591,0.486,121.361,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5191,3FdHgoJbH3DXNtGLh56pFu,Conga!,65,254000,0,MiamiSoundMachine,xgcedCGxFbqLbIQnRF,1985-08-13,0.789,0.656,2,-14.825,1,0.0474,0.168,0.0409,0.0311,0.865,122.237,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5192,23IK8TF2MSiLnuEjaYPfVV,Nightshift,64,306560,0,Commodores,twIAGnYuITpncMAsXnEm,1985-01-01,0.727,0.559,8,-10.194,1,0.0392,0.62,0.0114,0.0629,0.393,105.06,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5193,0sKfhhj6hYyJIXnTiZV9vf,The Sweetest Taboo,64,277373,0,Sade,zzsobNUcODyBTDvKx,1985-11-04,0.752,0.823,10,-9.455,0,0.0447,0.128,0.0098,0.303,0.962,91.563,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5194,0bvpSvOYt4KTfZIZJmyFOs,White Wedding,64,506227,0,BillyIdol,lzordPuZEXxwtaoVZYmG,1985,0.677,0.62,9,-11.766,1,0.0364,0.0335,0.0529,0.285,0.672,146.74,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5195,2avaSeKHI5l4sLruVfLdi2,Burning Heart - From "Rocky IV" Soundtrack,64,230720,0,Survivor,bcqnyjGBuRriQg,1985,0.651,0.665,9,-7.43,0,0.0269,0.221,7.91e-06,0.0403,0.647,97.996,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5196,0r5Ju8WyodpXBHmg3f4zYf,Kayleigh - 2017 Remaster,64,243560,0,Marillion,aiTWiOGgHdsAATS,1985-06-17,0.585,0.567,2,-8.35,1,0.0263,0.247,0.0023,0.102,0.564,106.127,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5197,5vI0C3TDTxySR6Oq8NWjE0,Hearts On Fire - From "Rocky IV" Soundtrack,64,252920,0,JohnCafferty,fPKTAseRcysASUpEw,1985,0.576,0.896,7,-8.026,1,0.04,0.0317,0.0,0.211,0.617,136.586,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5198,1qWLCuCnNcQVVzJm4pu7Zv,Luna de Miel en la Mano,64,316427,0,Virus,GALzQAsegiQlhOtV,1985-04-29,0.713,0.682,9,-8.649,0,0.0784,0.18,0.0258,0.195,0.252,177.314,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5199,15049rGLXHwrWtE4euUb5C,The Killing Moon,63,346280,0,EchotheBunnymen,fgYKFAvljexLWtbZ,1985-11-11,0.522,0.85,7,-4.769,1,0.0361,0.132,0.0338,0.295,0.71,124.216,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5200,0DfG1ltJnZyq4Tx3ZLL7ZU,Rock Me Amadeus - The Gold Mix,63,202236,0,Falco,hLdhVpRDGENeKGZLnW,1985-02-19,0.61,0.817,4,-9.45,0,0.133,0.296,0.00336,0.0884,0.89,176.735,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5201,0HoaLXRp7jJtdQFunUyUGc,The Sun Always Shines on T.V.,63,302400,0,aha,jzcTCTVFLXQlBNiIUzE,1985-06-01,0.494,0.839,9,-8.79,0,0.0647,0.0534,0.0706,0.253,0.219,126.329,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5202,2co8fDyaVmxv8xruQWORnC,Road to Nowhere - 2005 Remaster,63,260213,0,TalkingHeads,xSpqnPirlEpjHBwmSC,1985-07-10,0.654,0.789,2,-4.901,1,0.0322,0.0404,1.29e-05,0.119,0.579,110.378,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5203,1wncA7mz0ntqvZ8UzFokGk,Venezia,63,270680,0,HombresG,uhKYYSCqAgJNxcUDA,1985,0.581,0.826,1,-5.603,1,0.0816,0.224,0.00128,0.0506,0.573,168.561,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5204,4PBou1i63krEp3jKCPhxVD,Nada Personal - Remasterizado 2007,63,292573,0,SodaStereo,AnyvFhDYDolNmzKBp,1985-10-09,0.763,0.939,8,-4.826,0,0.0488,0.422,0.136,0.119,0.448,124.396,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5205,5tewIdMVsaJWN19ZnmnPNN,Hunting High and Low,63,228693,0,aha,jzcTCTVFLXQlBNiIUzE,1985-06-01,0.513,0.676,9,-6.148,0,0.0309,0.301,0.0,0.0864,0.311,116.592,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5206,0lqfBvf1Gqmmt3l5Qeirlm,R.O.C.K. In The U.S.A. (A Salute To 60's Rock),63,174360,0,JohnMellencamp,lPQFkJOwGWAFORFCqH,1985,0.432,0.958,9,-4.009,1,0.0819,0.00943,2.79e-06,0.227,0.874,164.018,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5207,7Di7t9yGoxdZRLAt5a4pi0,Manic Monday,62,184173,0,TheBangles,luqRxGaczYrpVIC,1985-07-11,0.685,0.571,2,-11.623,1,0.0299,0.335,2.38e-06,0.214,0.869,121.737,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5208,3KRJx4PjRJBFPGFQD0p02H,Why Worry?,62,509067,0,DireStraits,WwSkZLtFUFjGjMZBMtT,1985-05-13,0.591,0.132,4,-21.243,1,0.0296,0.934,0.553,0.271,0.106,93.714,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5209,4UXE0ZLGIoLUOFqTECzoQe,Pronta Entrega,62,273307,0,Virus,GALzQAsegiQlhOtV,1985-04-29,0.774,0.615,2,-7.614,0,0.0314,0.181,0.0107,0.141,0.703,136.851,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5210,76BYv24CcZt2u94JRjmATX,Madhouse,62,259760,0,Anthrax,JysSUOyfVsUQUaESheP,1985-10,0.329,0.885,9,-10.661,1,0.0904,0.0242,0.00433,0.735,0.481,163.538,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5211,22wWxHGHRH8gZXNDXRgSqY,These Dreams,61,254476,0,Heart,jwBbxjoYalTpcJFCPv,1985-07-06,0.535,0.532,11,-9.865,1,0.0291,0.508,0.0,0.0868,0.3,79.106,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5212,3c8JemHol1XwFFruXQxjCO,Everybody's Talkin',61,152227,0,HarryNilsson,RTzAwFprBqiskpeSJX,1985-01-01,0.496,0.368,4,-15.194,1,0.0338,0.46,7.54e-05,0.311,0.628,128.331,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5213,0TiRPD1YD6Ox3bUujwXCQa,Smokin' In The Boys Room,61,208400,0,MtleyCre,ccvwVNYlIcvrvtBL,1985,0.391,0.938,2,-4.86,1,0.0786,0.00175,1.09e-06,0.247,0.652,134.691,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5214,3D5ORNm9spaTcdRx50ksHx,Lay It Down,61,205560,0,Ratt,tufWJzpCiAGleBtTkmTn,1985,0.442,0.759,10,-13.475,1,0.0354,0.000402,0.0081,0.174,0.279,198.117,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5215,1MOSRjdAbUhvLNnHCdUEL5,Mistral gagnant,61,165933,0,Renaud,uNxhomvRvHkcdIer,1985-11-30,0.362,0.368,11,-12.878,0,0.042,0.861,4.99e-06,0.0937,0.393,82.751,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5216,3BGbqEDio3ocx1v4egIYr6,Walk Like an Egyptian,61,204560,0,TheBangles,luqRxGaczYrpVIC,1985-07-11,0.711,0.788,11,-14.705,1,0.0825,0.0117,2.05e-06,0.311,0.757,103.172,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5217,4umQbcdBF3YVsNBvvnFLiX,A Good Heart,61,281800,0,FeargalSharkey,zklgbVErerKRBqiKtT,1985-01-01,0.653,0.884,10,-10.224,1,0.0444,0.417,0.0,0.318,0.762,104.647,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5218,6a0lr0jt8lKDJhsAYA49NS,Jeanny,61,355989,0,Falco,hLdhVpRDGENeKGZLnW,1985-02-19,0.648,0.659,9,-10.456,0,0.0456,0.451,0.0,0.189,0.465,105.914,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5219,29d0nY7TzCoi22XBqDQkiP,Running Up That Hill (A Deal With God) - 2018 Remaster,61,300840,0,KateBush,aSxMhuvixZhdKjIDwL,1985-09-16,0.625,0.533,10,-11.903,0,0.0596,0.659,0.00266,0.0546,0.139,108.296,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5220,56BG1hMSEkIN7IA2E4xNuN,Baby's Got Her Blue Jeans On,60,179653,0,MelMcDaniel,fMdOvLUdwWjbMeNiup,1985-02-22,0.871,0.714,10,-6.413,1,0.0307,0.237,1.94e-06,0.072,0.962,106.797,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5221,55mXuPsEm6aboDIM68RM74,Je te donne,60,265400,0,JeanJacquesGoldmanMichaelJones,CxOTMqagpzlcGGAFvOjsrkofuPhHCKqW,1985-09-13,0.459,0.776,0,-5.385,1,0.0359,0.287,0.0,0.159,0.749,122.004,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5222,0qH487xSz8Z6Xk4kyOQkbG,Dirty Old Town,60,225426,0,ThePogues,wzMOQwNTZvVBamvhFAH,1985,0.511,0.464,7,-10.765,1,0.0383,0.256,4.2e-06,0.132,0.289,123.412,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5223,0HzjKCZmFhwcO2vnnHpj9q,Sara,60,292800,0,Starship,kObWapDEgEAJPBxzf,1985-09-10,0.642,0.805,10,-5.675,1,0.0336,0.352,1.02e-06,0.118,0.365,100.273,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5224,5atQ2haKP5LT65WM0KUts3,Cloudbusting,60,310160,0,KateBush,aSxMhuvixZhdKjIDwL,1985,0.68,0.248,1,-17.465,0,0.0328,0.696,8.88e-06,0.0839,0.812,112.806,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5225,6FnuMo55jNECTDdS1nD5H0,Dancing in the Street - 2002 Remaster,60,204787,0,DavidBowieMickJagger,oSGxfWSnnOXhDfKuzGydpbdHTmbzAGVUVvO,1985-08-12,0.6,0.816,4,-13.64,1,0.0431,0.117,0.0,0.126,0.744,130.99,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5226,3iC3Numiy9P3AkF7iioKmx,Wild Child,60,312400,1,WASP,BVkDHWRvLJEyKdvhLbjsq,1985,0.372,0.857,5,-7.816,0,0.0461,0.0608,9.01e-05,0.187,0.389,146.08,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5227,5WeBnrDPyLhxruxVryHCkn,La Bestia Pop,60,247067,0,PatricioReyysusRedonditosdeRicota,byQKddOblXCZEjehQ,1985-04-22,0.641,0.677,7,-10.142,1,0.0327,0.0506,0.112,0.0687,0.896,120.666,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5228,7uscfoAoI65JcSY4NyHg1t,Ainda É Cedo,60,237733,0,LegioUrbana,twEpCRgmSRZiZgnt,1985-01-01,0.612,0.675,2,-10.39,1,0.0388,0.32,0.00093,0.0861,0.803,148.336,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5229,3ZI3sK9ZJB3LOiZtCs9l3p,Every Time You Go Away,60,324347,0,PaulYoung,rqUHQNYGBnBzbrYa,1985-12-17,0.608,0.604,5,-12.285,1,0.0433,0.169,0.000133,0.106,0.673,164.254,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5230,1it9umP1j9qSqzKbSLLqqy,Chain Reaction,60,230533,0,DianaRoss,MdGsyQeRYPPcClLaUGl,1985-09-24,0.794,0.55,11,-12.988,1,0.0367,0.155,0.000271,0.113,0.744,127.736,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5231,6N5DRCQUSXT1qQqmqsO92B,Party All the Time,60,253293,0,EddieMurphy,ZqpfBlejCMrWdeAdphc,1985-02-05,0.699,0.692,11,-13.045,1,0.0456,0.00979,0.000326,0.0427,0.677,135.03,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5232,2ZIzyHDYsXIHUojfr6bAbO,Don't Lose My Number - 2016 Remaster,60,288547,0,PhilCollins,lxfqrEsLXNNOCSkILp,1985-01-25,0.585,0.832,5,-5.016,0,0.0814,0.168,5.09e-05,0.0634,0.952,80.614,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5233,09C7ULYG1WhWgngwkkvVxN,Rough Boy,60,289160,0,ZZTop,AMilvUzWuMRuqKtDgN,1985-10-28,0.457,0.48,9,-15.776,1,0.03,0.38,0.016,0.142,0.683,157.967,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5234,66rdGSb6FMm0neFXxmJdPQ,Who's Holding Donna Now?,59,267733,0,DeBarge,isUIjlIPjxNZOHIMV,1985,0.658,0.334,3,-14.648,0,0.0254,0.423,2.21e-05,0.127,0.647,90.173,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5235,2lnQcP5hr4RKR63TFvnI4k,Overjoyed,59,222586,0,StevieWonder,guDJrEfXqbFEbdPAqi,1985-09-13,0.221,0.264,10,-17.533,1,0.0332,0.541,0.0,0.148,0.169,83.128,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5236,53pZ8y3yMYUNpclGwIufu0,Conga,59,255760,0,GloriaEstefanMiamiSoundMachine,IFCkquJxdWeYMkIxgcedCGxFbqLbIQnRF,1985,0.791,0.86,2,-8.282,1,0.0451,0.118,0.105,0.0614,0.906,122.3,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5237,2Qu65QrO1DiWVJIteOD9ri,Twinkle, Twinkle, Little Star,59,71160,0,Raffi,oWSqrgMuIEyHqpnue,1985,0.728,0.0392,0,-22.703,1,0.0354,0.964,0.0431,0.167,0.484,97.764,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5238,3X9XJLwQPWqRnsNaL9z6ss,Trois nuits par semaine,59,312533,0,Indochine,knmbOGekGmKvACB,1985-12-10,0.74,0.783,9,-13.726,0,0.0292,0.0176,0.000645,0.0877,0.906,137.292,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5239,14g6foD6sxO1qgkDKuPgWv,Swingin Party - 2008 Remaster,59,233573,0,TheReplacements,WPYNTKUjaxMQTZ,1985,0.647,0.69,6,-8.657,0,0.0454,0.0224,0.0,0.147,0.682,117.514,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5240,3Od5XBElZqm5N6rr86LS5r,Rain,59,236467,0,TheCult,DWKvkyjHOmKJnSyS,1985-10-18,0.561,0.845,0,-6.981,1,0.0328,0.000648,0.823,0.347,0.605,122.731,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5241,5PKtqiUwkjveVYzmj4gMnz,Training Montage - From "Rocky IV" Soundtrack,59,219080,0,VinceDiCola,QnBzXfyXGIEfKpHqeHn,1985,0.578,0.748,7,-8.702,1,0.0546,0.0145,0.723,0.11,0.345,81.107,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5242,6IeJcGYibtUKl9QnAupnYi,Si no te tengo a ti,59,286480,0,HombresG,uhKYYSCqAgJNxcUDA,1985-01-01,0.822,0.506,9,-10.595,1,0.0426,0.493,0.147,0.103,0.263,128.026,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5243,4M2tEAdFRdg0U8rAgYa8o2,Duel,58,288227,0,Propaganda,yIUgPYZqgJoNZjeBvrHn,1985-07-01,0.672,0.697,5,-11.321,0,0.0343,0.252,0.407,0.118,0.528,144.873,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5244,0ZYf6N5eBeXStMri0mf3DZ,Voices Carry,58,263573,0,TilTuesday,LysrZMyhXUnYGvIP,1985-06-01,0.583,0.574,0,-9.044,1,0.0239,0.0282,2.14e-06,0.114,0.578,104.995,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5245,5BYOLEoFD1fWokKncxz7BQ,You Look So Good In Love,58,193400,0,GeorgeStrait,vngPClqofybhPERIqQMYd,1985-01-01,0.642,0.233,9,-16.568,1,0.0298,0.435,0.0,0.105,0.333,114.495,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5246,2s6wCS3vDZFPY9NOTlPXJZ,Take Me Home - 2016 Remaster,58,353573,0,PhilCollins,lxfqrEsLXNNOCSkILp,1985-01-25,0.62,0.807,8,-7.753,1,0.0548,0.471,0.108,0.0477,0.579,118.796,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5247,1XR1X1VTyTOVdPgH18RdME,Is It a Crime,58,381133,0,Sade,zzsobNUcODyBTDvKx,1985-11-04,0.452,0.377,5,-10.138,0,0.0324,0.22,0.00588,0.212,0.532,122.423,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5248,1fU9wVDi3yZrawv1Rc4vcS,Elle a les yeux revolver,58,219973,0,MarcLavoine,KEYZLtgythgGZzrFXf,1985-01-01,0.577,0.273,5,-16.428,1,0.0499,0.496,0.0,0.0914,0.547,79.995,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5249,1RbOObDFn7GOseR1w529Zj,Things Can Only Get Better,58,235827,0,HowardJones,loBFiQdEWSXfNKqY,1985,0.752,0.743,7,-6.083,1,0.0331,0.0314,0.000117,0.128,0.832,108.254,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5250,3khgsGxNwXijlqyStMvpfh,El Ultimo Cartucho,58,201067,0,LosInvasoresDeNuevoLen,CGtBYmVPeLhIkMFnGv,1985-01-01,0.681,0.496,8,-8.373,1,0.0551,0.751,0.0,0.0709,0.921,183.38,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5251,0ogTZlmFqg5xyFCMpRAEb4,Grandpa (Tell Me 'Bout The Good Old Days),58,258333,0,TheJudds,MSTObsbDOJQTxLsIc,1985-10-30,0.56,0.239,4,-16.732,1,0.0347,0.473,1.37e-05,0.0565,0.601,201.672,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5252,5nNZTUzinBDsnj3U76NJFC,And She Was - 2005 Remaster,58,219413,0,TalkingHeads,xSpqnPirlEpjHBwmSC,1985-07-10,0.697,0.846,9,-5.471,1,0.03,0.0059,0.0256,0.0967,0.973,126.467,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5253,0GvWnt7XpoHAa72mvax2Uz,Good Golly Miss Molly - Remastered,58,128867,0,LittleRichard,xlsYeWRyyyYMpAMm,1985-01-01,0.555,0.897,7,-7.985,1,0.0483,0.617,0.00112,0.334,0.965,166.386,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5254,7J5B4k0AT8KIoV5KiUa4o7,You're a Woman,58,321840,0,BadBoysBlue,OXILsPDWNJXiGMAkCWa,1985-11-15,0.737,0.309,0,-12.437,0,0.0426,0.0297,0.000511,0.313,0.763,118.218,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5255,362zcsyXMLbL7PNLhOovvm,Computer Love,58,282308,0,Zapp,KhmwGUvcMUULwyi,1985-01-01,0.679,0.709,7,-5.851,0,0.133,0.676,0.0,0.292,0.673,84.543,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5256,0aF9m87P8Tja3NUMv4DfHt,Head Over Heels / Broken,58,302120,0,TearsForFears,bthkUfsYUYdcFyqxmSUU,1985-02-25,0.298,0.704,7,-9.905,1,0.0366,0.188,0.000488,0.777,0.655,95.023,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5257,6pPCOXIQeNMr1oCWJTomSf,Sisters Are Doin' It for Themselves - Remastered Version,58,357147,0,EurythmicsAnnieLennoxDaveStewartArethaFranklin,NKDgyjhDLnNqubBMspMQqdVbdwPaxGXqumgcCQIlkkfbulMtjBQkgnwUJBmHEZxDfcyok,1985-04-29,0.67,0.903,10,-5.796,0,0.0402,0.0129,0.0,0.331,0.953,136.193,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5258,3BSoskNONnjn05yRO2tYFX,Don't Come Around Here No More,58,307333,0,TomPettyandtheHeartbreakers,tXTplrkIPvBNCe,1985-03-26,0.502,0.54,10,-15.93,1,0.0318,0.00105,0.00849,0.243,0.922,160.531,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5259,4ztwMHfPZhPoruZdBbgriM,Three Times A Lady,58,217427,0,Commodores,twIAGnYuITpncMAsXnEm,1985,0.39,0.0803,8,-20.518,1,0.0306,0.874,0.000639,0.127,0.184,150.503,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5260,0ZKHCt987c5ili0AegnZbb,El Breve Espacio en Que No Estas,58,242960,0,SilvioRodrguezPabloMilans,rUyBlggMtZUHQZnZuOvOfKhwzlTcdqBEwsC,1985-10-18,0.383,0.291,7,-9.93,1,0.0368,0.807,0.0,0.35,0.305,73.638,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5261,5xkNd7kCRmjT2DxSAYVVyC,And We Danced,58,227760,0,TheHooters,uhvDINTTiDXBrPfquN,1985,0.561,0.945,9,-6.086,1,0.0444,0.0869,0.0,0.22,0.723,145.781,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5262,1ZzSTURCWH0Xax2i69ooSE,Me Vas a Echar de Menos,57,175067,0,JosJos,mNqcMxWXoToqfDPMyV,1985-04-27,0.574,0.656,9,-6.833,1,0.0335,0.534,6.75e-06,0.21,0.3,104.349,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5263,3D3lmTEhuWaunO1yxpYPD8,You're in Love,57,194107,0,Ratt,tufWJzpCiAGleBtTkmTn,1985,0.567,0.867,7,-11.541,1,0.0484,0.00384,0.088,0.112,0.535,146.008,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5264,2u9MJ3AMjrKeVGEAntelyM,Money's Too Tight (To Mention) - 2008 Remaster,57,252960,0,SimplyRed,facOhromAZdqxRAvv,1985,0.761,0.813,2,-6.018,1,0.0299,0.322,0.00219,0.0588,0.878,113.415,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5265,2vDaSr8NzCzG2rFtqup2Kq,Cuando Sale la Luna,57,185307,0,JosAlfredoJimenez,TwhbsUiufLjQtz,1985-07-25,0.472,0.172,9,-18.132,0,0.0449,0.809,0.0,0.103,0.504,106.875,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5266,4OYRJv1tcOEPe38Fwc7y1m,White Wedding (Parts 1 And 2) - Shotgun Mix / 24-Bit Digitally Remastered 2001,57,505093,0,BillyIdol,lzordPuZEXxwtaoVZYmG,1985,0.672,0.792,9,-6.436,1,0.0333,0.0175,0.0119,0.313,0.649,146.907,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5267,1weEqgqTn03x8hmJ2mHMET,Stay,57,217427,0,OingoBoingo,LXEAEGrpKQtpyCusZuWu,1985-01-01,0.579,0.541,5,-11.54,1,0.0285,0.386,1.51e-05,0.129,0.659,119.148,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5268,6JFfOp1LTXnyDCTfHlOc9j,Josephine,57,237560,0,ChrisRea,KEGGLDYlHgFDqZyEEs,1985-07-18,0.656,0.469,3,-15.941,0,0.0281,0.0223,0.00866,0.0475,0.66,110.037,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5269,39YibHWQJLIgjQ0xWKlq6t,Juegos De Seducción - Remasterizado 2007,57,198107,0,SodaStereo,AnyvFhDYDolNmzKBp,1985-10-09,0.61,0.893,11,-4.589,1,0.0466,0.0993,0.0224,0.0929,0.572,100.934,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5270,2KzUa9x2TNzHVsx4sVuHsx,Encore et encore - Remastered,57,273680,0,FrancisCabrel,uoNwSONVNfvSHHMQrHAv,1985,0.7,0.794,8,-8.191,1,0.0484,0.479,0.00028,0.0921,0.858,164.287,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5271,3OS4XXm4S42pnESQmtN9MG,Well I Wonder - 2011 Remaster,57,239427,0,TheSmiths,yYgUcIsjMrhjoPoJ,1985-02-11,0.643,0.59,11,-10.843,0,0.0284,0.0806,0.00578,0.174,0.818,126.651,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5272,5uh98HlgvoJd2zRWAduj2Y,Bring on the Dancing Horses,57,235800,0,EchotheBunnymen,fgYKFAvljexLWtbZ,1985-11-11,0.568,0.925,2,-5.274,1,0.0402,0.00635,0.00495,0.315,0.752,118.45,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5273,5yFI0Vs3x4EbeIDerT0ck1,Codinome Beija-Flor,57,151307,0,Cazuza,PwOUfFbmaGkKwkbbfU,1985,0.482,0.255,11,-9.793,0,0.031,0.946,9.67e-05,0.107,0.301,95.205,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5274,6Xj4KkWScUvO3LiowRl7GK,Por Ese Hombre (with Dyango),57,289747,0,PimpinelaDyango,ECVSqFdLyhKAEuTMoPbOlSBsJPgyqdEypJJVb,1985-04-14,0.551,0.442,0,-8.9,0,0.0295,0.543,0.0,0.063,0.422,96.333,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5275,0WnVjkW8k8Zo37JAI7K8zF,Secret,57,236333,0,OrchestralManoeuvresInTheDark,wJNwdRWtNNunmXuwBk,1985-06-17,0.717,0.651,9,-8.597,1,0.0284,0.276,0.00272,0.0488,0.904,114.471,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5276,78SCz6GkX5zPta7X1DsZnZ,Que Te Vaya Bonito,57,159333,0,JosAlfredoJimenez,TwhbsUiufLjQtz,1985-07-25,0.473,0.257,5,-16.107,1,0.0524,0.623,8.68e-06,0.0727,0.806,133.577,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5277,4fFxkU9C7prSviiYtvlV8V,Johnny Come Home,57,211507,0,FineYoungCannibals,pDKrECGuOjHtxsyTp,1985-01-01,0.775,0.882,10,-6.96,1,0.0458,0.00898,0.000247,0.0628,0.963,133.62,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5278,20JrcZW9Djp70GZyFRrAfl,Johnny B.,57,237467,0,TheHooters,uhvDINTTiDXBrPfquN,1985,0.473,0.855,9,-6.221,0,0.0293,0.136,4.5e-05,0.292,0.521,91.744,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5279,0RbaD2rw0HmpfflXFH9DKu,The One I Loved Back Then (The Corvette Song),57,150520,0,GeorgeJones,OpqcUtjHHvGGhVYC,1985-08-01,0.644,0.468,2,-11.824,1,0.0953,0.517,0.0,0.162,0.959,159.498,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5280,2h47SG8bNphmicAll4H9RV,Dead Man's Party,56,381627,0,OingoBoingo,LXEAEGrpKQtpyCusZuWu,1985-01-01,0.568,0.863,1,-10.984,1,0.0383,0.5,0.000137,0.246,0.923,161.261,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5281,5jmuiCbNU1SEvFKqMadOZR,Mi Viejo,56,190653,0,VicenteFernndez,PPoILuYeFXVZRl,1985,0.539,0.423,2,-7.646,0,0.0277,0.684,0.0,0.323,0.408,95.834,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5282,0g8Q1Pmem92k7PzI3VLWKz,All at Once,56,268600,0,WhitneyHouston,XpaIBNiVzIetEPCWDvAFP,1985-02-14,0.58,0.325,0,-16.16,0,0.0294,0.539,0.0,0.135,0.342,132.548,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5283,2rkw1gqH62Tc9ydm9jsEJ1,Tous les cris les S.O.S.,56,302866,0,DanielBalavoine,IqYhzqUUbbYmRgn,1985-10-01,0.447,0.442,9,-10.76,0,0.0308,0.563,4.5e-05,0.225,0.404,176.245,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5284,2nIDPfhjHZP8UOXPenLZUC,I Drink Alone,56,275493,0,GeorgeThorogoodTheDestroyers,nsvBAGGIYxGxgrQaRK,1985,0.344,0.796,9,-11.731,1,0.0407,0.00942,0.00186,0.0984,0.601,96.95,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5285,0qXUwQbZHFnhAGCgqwz2lR,Meet Me In Montana,56,236627,0,DanSealsMarieOsmond,yEsJBqynJPswhHzqiijYRxOagYoFOgSEkWj,1985-01-01,0.661,0.389,10,-12.292,1,0.0301,0.393,1.04e-06,0.0902,0.515,124.147,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5286,1D2QnxvMOac95EG9C0KbsJ,So In Love,56,209360,0,OrchestralManoeuvresInTheDark,wJNwdRWtNNunmXuwBk,1985-06-17,0.599,0.805,5,-7.07,1,0.0277,0.0863,0.0013,0.566,0.962,120.049,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5287,5nN1jGnCadYk1jYm6oV5zN,What About Love?,56,221671,0,Heart,jwBbxjoYalTpcJFCPv,1985-07-06,0.246,0.631,2,-7.067,0,0.0377,0.295,0.0,0.321,0.3,160.633,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5288,2LbkpJUH052AvFcNIgjHTO,Mony Mony - Downtown Mix / 24-Bit Digitally Remastered 2001,56,301800,0,BillyIdol,lzordPuZEXxwtaoVZYmG,1985,0.742,0.743,10,-6.293,0,0.0508,0.00935,0.0,0.22,0.485,135.012,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5289,46NfUryLlW7aiI8xD8UFhL,Como Me Haces Falta,56,235427,0,LosBukis,kOCiqZauYsokSeZuKf,1985-01-01,0.662,0.452,4,-13.051,1,0.0261,0.474,0.0,0.467,0.618,97.115,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5290,4d0DpU7Odiv0ztvX2GxJlk,Exagerado,56,223400,0,Cazuza,PwOUfFbmaGkKwkbbfU,1985,0.678,0.663,7,-7.726,1,0.0307,0.0874,0.0161,0.615,0.822,136.388,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5291,0deI3lZkgbVt6wRsv5s0Ev,Out In The Fields,56,257707,0,GaryMoorePhilLynott,wrRJZgPmYvVFyNkQjyVrXXZQeaRiDykzH,1985-01-01,0.439,0.947,2,-8.189,0,0.0627,0.0275,0.00579,0.394,0.359,179.997,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5292,05OmZz1tixVBtXMx3cb4oc,Plus près des étoiles,56,237827,0,Gold,jByDdpRNXrovxxcHb,1985,0.44,0.845,11,-6.726,0,0.051,0.0114,0.0,0.252,0.342,116.07,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5293,3yOzDXX8cTz25jid6uKTFD,Greatest Love of All,56,296600,0,WhitneyHouston,XpaIBNiVzIetEPCWDvAFP,1985-02-14,0.534,0.399,9,-10.45,1,0.0324,0.682,0.0,0.172,0.29,130.961,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5294,0VWPd2zYt1430jL6XtUjep,Bop,56,226267,0,DanSeals,yEsJBqynJPswhHzqi,1985-01-01,0.805,0.575,1,-11.882,1,0.0304,0.346,0.0,0.109,0.975,123.203,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5295,2kLN6dEwdgyTbPnFZ1BONy,Apples And Bananas,56,98040,0,Raffi,oWSqrgMuIEyHqpnue,1985,0.844,0.136,5,-14.548,1,0.067,0.749,5.24e-06,0.0871,0.926,140.109,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5296,3sR4DlHGETLGfncj2PFqnI,All The Love In The World,56,211267,0,TheOutfield,zxDewzdjZdSBGaYcry,1985,0.601,0.714,4,-7.848,1,0.0392,0.0212,0.0,0.0881,0.645,128.21,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5297,3fPqUl4lPDUQmY0T7dKUv2,Downtown Train,56,230000,0,TomWaits,xXhcMbOTlUdYsPTuZM,1985-09-30,0.665,0.43,3,-13.62,1,0.117,0.465,0.0488,0.0965,0.701,115.399,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5298,5oHH3wAhMt2McYsA6bBKMw,Temblando,56,190080,0,HombresG,uhKYYSCqAgJNxcUDA,1985-01-01,0.42,0.258,9,-9.098,1,0.0377,0.833,6.24e-06,0.112,0.182,175.225,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5299,7hoWkhuHv9b3jiCbxX1kMm,It's All Over Now Baby Blue,56,229960,0,MarianneFaithfull,mlgepeaoNgzTsYMRB,1985,0.651,0.414,2,-10.572,1,0.0301,0.524,0.00267,0.118,0.445,111.175,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  5300,2HUNIj9v8qlJnpuslgcSIX,The Man Who Sold the World,56,343867,0,MidgeUre,NisfpypyuDVpBofqEN,1985-10-19,0.535,0.503,2,-8.595,0,0.0354,0.0495,0.267,0.341,0.333,112.97,4
# ghgjhh
# Message Type:  <class 'str'>
# ...
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6678,1jL4dBrmBpkAwxiMFzHulz,Rockollection,55,250747,0,LaurentVoulzy,ogXCiVOazafPmMNHphZ,1989-05-11,0.765,0.54,0,-12.114,1,0.0984,0.103,0.0,0.373,0.788,129.48,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6679,5TZbtpZcTWKEn81Du4hiTb,Mr. Moustache,55,203929,0,Nirvana,olETJLqEDrqDCTFyPh,1989-06-01,0.194,0.898,0,-6.12,1,0.0608,5.58e-06,0.141,0.108,0.482,177.191,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6680,2nH0c41fDJ93zov0tULRdZ,Un Golpe Más,55,154307,0,Bronco,VKhCQDiMkUvaBMoKV,1989-01-02,0.657,0.538,10,-12.941,1,0.0405,0.156,2.76e-05,0.0786,0.902,91.962,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6681,2e8MxBgVWMSQmxb2zcuCoq,Die Walkure, Act III: Ride of the Valkyries,55,325000,0,RichardWagnerBudapestSymphonyOrchestraGyrgyLehel,CxMVkqlAiABuTwDgEyrzlxPNmulLRpnwmEAXVeudeVpYxBNIQldF,1989-01-01,0.251,0.219,7,-16.781,1,0.0323,0.929,0.933,0.0824,0.0965,89.997,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6682,1ESnzI19ZEuAi8gvJWwZ9v,A Cambio de Que,55,215733,0,Marisela,cMjCAFNyKYIsnBlqG,1989,0.687,0.308,3,-15.984,1,0.0343,0.656,2.36e-05,0.0844,0.486,136.535,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6683,5yqVF4y7dq6AgnNCHnHZEA,California Blue,55,235907,0,RoyOrbison,JDkhLrjiPNEpjAgJnS,1989,0.651,0.596,2,-12.561,1,0.0271,0.67,1.27e-05,0.376,0.695,105.679,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6684,020aPMXlwYFpPB7cI8Kuc1,El ritmo del garaje,55,293533,0,Loquillo,FvDQZBucDlidtOUCZr,1989-02-22,0.575,0.718,7,-3.566,1,0.0545,0.0381,0.000504,0.1,0.962,140.885,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6685,5Oc0vLGWdEWeCqIU8zyELt,Hound Dog,55,181000,0,BigMamaThornton,bRcgMtkCVpmIyrDNzO,1989-01-01,0.563,0.542,9,-10.862,1,0.0962,0.706,3.59e-05,0.355,0.785,133.285,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6686,6tAug9ksGLZb2z1RfPZJMo,Bem Que Se Quis - Ao Vivo,55,217867,0,MarisaMonte,rSTXALHuEKAawPLBdODH,1989-01-01,0.376,0.39,8,-18.582,1,0.113,0.15,0.0,0.679,0.498,85.211,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6687,4k0bXm9Q4RaTuYi09i4lKK,Jump (For My Love),55,262618,0,ThePointerSisters,kreKeandXjcyAUjN,1989-09-21,0.86,0.705,10,-12.514,0,0.0894,0.107,8.87e-06,0.149,0.854,134.395,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6688,4YopYXMzcifG1jm94vnhbW,Un Fin de Semana,55,201027,0,Bronco,VKhCQDiMkUvaBMoKV,1989,0.437,0.604,5,-9.217,1,0.0283,0.458,7.46e-06,0.276,0.678,146.86,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6689,1ieaNRjnBSPwznI7BQrEWi,Monte Castelo,55,230627,0,LegioUrbana,twEpCRgmSRZiZgnt,1989,0.45,0.345,0,-14.813,1,0.0288,0.0742,0.0,0.354,0.507,92.675,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6690,46Qy1xAr2K7rylRYwdQ6Gw,House of Pain,54,346627,0,FasterPussycat,FwGBBwUviGVIeDIByOu,1989-08-01,0.519,0.61,0,-10.256,1,0.036,0.0766,6.49e-05,0.248,0.232,121.324,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6691,5oheUEVCpJllnImTs5nNiS,Why'd You Come in Here Lookin' Like That,54,152507,0,DollyParton,vWCbZhxZogkzPsEU,1989-05-30,0.615,0.759,4,-7.722,1,0.045,0.693,0.0,0.0848,0.96,175.249,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6692,7pfP8Z9M9KRUtzTLcnjem5,So Alive,54,257827,0,LoveandRockets,mvgMBvJkxarNIDGdwPWg,1989-09-04,0.698,0.567,10,-13.968,1,0.0296,0.00548,0.234,0.147,0.919,118.826,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6693,3J9q29HbV4msJXTr2KDvy2,Si tú no estás aquí,54,264613,0,ngelesDelInfierno,qzYtiwABDEqlLJpZY,1989,0.478,0.607,4,-8.138,0,0.0242,0.0536,6.26e-05,0.215,0.262,91.138,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6694,4BYmnYGNVBVm2JHVxFNMXj,The House Is Rockin',54,143227,0,StevieRayVaughan,fsDcuclIeZiBDPK,1989-06-06,0.336,0.909,4,-11.019,1,0.039,0.204,0.0211,0.333,0.956,172.162,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6695,5ZOOjqoCaUydmo8bxSdosj,The Toxic Waltz,54,290280,0,Exodus,SNHJHrNyJTrXHPBH,1989,0.262,0.988,11,-4.922,0,0.253,0.00655,0.897,0.132,0.227,91.319,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6696,7xi6IGgGdjEHDxRSRTjf6i,Ah Bu Şarkıların Gözü Kör Olsun,54,328773,0,ZekiMren,ZZDIoDxGrXYTodWrL,1989-11-22,0.393,0.568,2,-11.864,0,0.0728,0.638,3.4e-06,0.32,0.591,83.395,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6697,6i1uWZYWabNHq2wQnoca58,It's Only Love - 2008 Remaster,54,298573,0,SimplyRed,facOhromAZdqxRAvv,1989,0.666,0.884,9,-5.243,0,0.0429,0.506,0.00612,0.0408,0.754,92.005,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6698,3xGwSN1dDdpN2s8oP8DRrC,Dheere Dheere Se Meri Zindagi Mein Aana,54,329640,0,AnuradhaPaudwalKumarSanu,hkBbReklJChjaunCnKblSRoklNdpwmzLxwfn,1989-12-26,0.477,0.636,8,-8.334,0,0.0356,0.865,0.00226,0.208,0.707,84.547,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6699,1sQ5WUWw3JrsSEhdiQlfRt,I'll Never Find Another You,54,162320,0,TheSeekers,dedWAqdIKTdCiqiadUrV,1989-01-30,0.567,0.672,10,-7.666,1,0.0336,0.75,0.0837,0.367,0.79,126.509,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6700,433EQGQOsQjWvD5eImXkHf,This Is the One - Remastered,54,299320,0,TheStoneRoses,lYTALVDUfxrdoRPd,1989-05-02,0.247,0.784,9,-7.452,1,0.0514,0.00133,0.0369,0.558,0.345,126.679,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6701,7A2yhrdnFspRjpX8RC8UW1,Otis,54,256267,0,TheDuruttiColumn,fhbwXqVtLxxspbTe,1989-01-01,0.47,0.391,10,-9.131,1,0.0374,0.685,0.765,0.479,0.0769,122.472,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6702,4PyhlL1vrSvPlhYLdphszr,Big Fun,54,206160,0,InnerCity,vUJQLNMlRfjOcLjGWp,1989,0.677,0.935,3,-11.55,0,0.0514,0.0787,0.376,0.0787,0.965,120.11,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6703,4h7bZNHnYP2umOomPbnfxG,Epic,54,293653,0,FaithNoMore,GbCJZrIYbmmYOf,1989-06-20,0.358,0.893,4,-7.486,0,0.12,0.0222,0.0524,0.126,0.262,174.238,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6704,1e94BlwdHDMcadDh2abL4Q,Please Be Careful With My Heart,54,216440,0,JoseMariChanRegineVelasquez,EHAbAGMYOfkhdseNfSwNylAjJXPiCpMKxLrfp,1989,0.573,0.331,7,-13.529,0,0.0248,0.655,0.0,0.0865,0.361,99.578,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6705,5ulZo7nk3MByXLvja3NCAc,Hey Ladies,54,227773,0,BeastieBoys,riKLgPTnUKsx,1989-07-25,0.949,0.728,1,-10.653,1,0.211,0.286,0.0,0.0465,0.795,101.718,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6706,7IDM8csQeBILlNI2W1KAHb,Just Around The Corner - European Edit,54,253227,0,CockRobin,MOoTIFOvJATvyRXPPXg,1989-12-27,0.649,0.774,1,-6.908,1,0.0336,0.0757,0.000244,0.0601,0.547,122.096,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6707,2UC0OxMpQeSYft4pRswyEX,Sabor de amor - 1984 Version,54,219640,0,DanzaInvisible,MKJOpjFgUDbLiym,1989-01-01,0.637,0.482,9,-11.159,1,0.0378,0.12,0.0,0.158,0.832,133.799,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6708,0tp9eoX9x9RZ2STDVarBBs,Nobody Weird Like Me - Remastered,54,229960,1,RedHotChiliPeppers,LExTjHddEcZwqJJ,1989-08-16,0.167,0.975,2,-4.279,1,0.216,0.000169,0.0161,0.172,0.0918,199.06,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6709,6YoBe1FqFL5w10bQbemW16,Maldòn - Version originale,54,245200,0,ZoukMachine,gxlENRdJmiADhi,1989,0.779,0.639,9,-12.37,0,0.0555,0.155,0.000275,0.315,0.848,132.714,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6710,6C4BcBBnlNG0bwfZyeKSti,Do You Remember? - 2016 Remaster,54,276000,0,PhilCollins,lxfqrEsLXNNOCSkILp,1989-11-20,0.677,0.5,5,-7.839,1,0.0248,0.117,0.0109,0.0648,0.525,93.051,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6711,0gTEvnqaTPmrDvzbKZtQuw,The Ballad Of Jayne,54,274107,0,LAGuns,TEmHXBBLjTecLOAuMdS,1989-01-01,0.474,0.369,6,-14.216,1,0.0296,0.0291,5.86e-05,0.128,0.156,61.207,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6712,5YwcNVpjiqGqC2Ma9330j0,Young Years,54,238600,0,Dragon,HMYOaiqowUmcdtbt,1989,0.522,0.721,7,-11.835,1,0.0297,0.00233,0.00146,0.0999,0.516,140.066,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6713,7feSbMqJGg9yL0s6ypxy9S,Girls on Film,54,207787,0,DuranDuran,lZoBsPzoRJMlxwoT,1989-11-13,0.708,0.855,11,-6.301,0,0.0931,0.00548,0.0477,0.0447,0.656,131.955,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6714,2C8ymluZHrPz34w5tfk5QD,Sexy,54,331333,0,Westernhagen,ElbDJPlTKVYyEPWxfAS,1989-08-25,0.842,0.517,0,-12.567,1,0.0347,0.0735,5.28e-06,0.226,0.855,120.182,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6715,0KBqXXKYkzr79w2544bcqW,Nuestro Juramento,54,195937,0,JulioJaramillo,HqPNOoOVrPbEYMPT,1989-02-08,0.836,0.311,11,-16.273,0,0.0393,0.77,0.00144,0.0676,0.772,125.176,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6716,0rb2T3VwlC9jcA02UojwtE,Gitme Sana Muhtacım,54,271920,0,ZekiMren,ZZDIoDxGrXYTodWrL,1989-12-22,0.27,0.384,11,-14.961,1,0.0798,0.0639,0.000618,0.117,0.41,175.59,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6717,1GcL18n7WMpc6xRwY7D0bE,El Satánico Dr. Cadillac - Remasterizado 2008,54,241333,0,LosFabulososCadillacs,FShaXFYbyOsUAkuYqZ,1989-06-18,0.786,0.942,7,-3.751,1,0.0509,0.134,0.0223,0.0476,0.884,116.294,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6718,60HibhiSF8eBC2w4DWgorI,Cadillac solitario,54,214560,0,Loquillo,FvDQZBucDlidtOUCZr,1989-02-22,0.393,0.828,11,-4.147,0,0.0332,0.0746,0.00192,0.148,0.473,129.743,1
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6719,61K6lqGyrl2Aerk0LjAZem,Rollin' Stone,54,188160,0,MuddyWaters,yJjwRAwOdssiSmNR,1989-11-07,0.629,0.0192,4,-19.952,1,0.0833,0.989,4.3e-05,0.106,0.335,169.254,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6720,1gqk2dawfdLdn4XamF27cx,Nick Of Time,53,232867,0,BonnieRaitt,KDyYWRIpxZxrdYbKrqY,1989,0.886,0.312,9,-16.094,0,0.0579,0.37,0.00208,0.103,0.783,117.692,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6721,79ncJXSGJWqLXUxRXgvfLC,Gente di mare,53,238040,0,UmbertoTozziRaf,wsdZmWArooTmiSTldrlKqNmhaPUiCwFQyFS,1989-05-01,0.467,0.343,4,-10.454,1,0.0341,0.487,0.0,0.119,0.385,173.643,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6722,7eq81ADQrugi0YHqmA1Oy1,Berceuse for Piano in D-Flat Major,53,343000,0,MilyBalakirevChristianSpring,VFnwupwFPAtMivmXqieLerDCxcvEVklWhyPT,1989,0.3,0.0179,1,-28.318,1,0.0602,0.993,0.876,0.119,0.0398,79.853,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6723,359vq12J0koGowGV9pxek4,Ya No Me Interesas,53,184560,0,LuchaVilla,LYsttKhPVXOfqDkTCr,1989,0.704,0.31,9,-12.659,0,0.0365,0.236,0.0,0.11,0.924,127.462,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6724,3h7tr47MIwSz0i53YzliBg,The Healer,53,340293,0,JohnLeeHookerCarlosSantanaTheSantanaBand,yNOfXGQNGjAynkwvxyGQgQiiKpgkJXfhJkplBgEAhmHralJpDdE,1989-01-01,0.576,0.49,0,-14.862,1,0.0434,0.381,0.0153,0.0806,0.683,107.937,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6725,02dVj5B3vXOjylEFYCCsYQ,Prélude à l'après-midi d'un faune, L.86,53,644333,0,ClaudeDebussyTimothyHutchinsOrchestreSymphoniquedeMontralCharlesDutoit,UffEOsvdrtAupatMPTBUPcNwmGTIjQnWIAcXapeiUxnWecvAEBdKuVBNLcfGXRhpBxXEQ,1989-01-01,0.102,0.0259,8,-30.196,0,0.0444,0.964,0.864,0.0972,0.0319,90.128,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6726,4OID5ZgFFWJzAH5jdetEAn,Corcovado,53,188080,0,GalCostaAntnioCarlosJobim,bkppDUwthWaxTiWQhDpOVjZwOHCMBXOvbMISG,1989,0.452,0.182,0,-21.331,1,0.0499,0.837,0.000182,0.973,0.248,130.993,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6727,5zHgT1ibsBrSOEnQwZapto,Veronica,53,189507,0,ElvisCostello,BGRfQgtzikzpzADkaEn,1989-02-06,0.63,0.757,0,-6.731,1,0.0359,0.128,4.9e-05,0.355,0.737,153.989,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6728,1xHo7y2iFUfcSqb5WtYxID,The Promise You Made,53,232933,0,CockRobin,MOoTIFOvJATvyRXPPXg,1989-12-27,0.708,0.54,0,-9.036,1,0.0389,0.38,0.0575,0.158,0.616,117.016,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6729,0gbrepTKKXEYFQJ6tNCbid,No Control,53,106693,0,BadReligion,yJwXpWAQOOlXFzbCxLs,1989,0.459,0.966,11,-3.678,0,0.0924,0.0207,0.0,0.215,0.729,147.624,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6730,3EgvmOhP3NQUHY7d6PDOUg,Me So Horny,53,276467,1,LIVECREW,DxHPzeOOdbpDYYEes,1989-03-20,0.941,0.727,0,-11.592,1,0.228,0.00472,0.000811,0.177,0.623,128.746,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6731,5azaQP9aqjy3XYwsuJ0ebJ,Yellow Moon,53,244267,0,TheNevilleBrothers,dolqhURDeeHOtaQxg,1989-03-14,0.689,0.585,7,-15.142,1,0.0543,0.217,0.0189,0.314,0.892,90.373,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6732,68O1r5xQADu0JjvBibg9zN,Something's Gotten Hold of My Heart,53,280489,0,MarcAlmondGenePitney,nBZYpVAHbDQlDMpilapNzHNVQAxVzgSe,1989-01-30,0.565,0.492,4,-12.548,1,0.0254,0.148,0.0,0.0684,0.364,98.247,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6733,6bsiPYRqISKkHN9FpgffKP,Ellos Dicen Mierda,53,279000,0,LaPollaRecords,vHlZNpTazOleVxiEdJ,1989,0.284,0.727,11,-10.903,1,0.037,0.39,0.618,0.119,0.423,143.477,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6734,3AgvZyLH4sWkII5bnU80aQ,I'm So Excited,53,233533,0,ThePointerSisters,kreKeandXjcyAUjN,1989-09-21,0.581,0.7,7,-10.723,0,0.0377,0.107,0.0031,0.118,0.924,182.415,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6735,7FMXSSzIRW8aJwUPfzXsa2,She's a Mystery to Me,53,254960,0,RoyOrbison,JDkhLrjiPNEpjAgJnS,1989,0.431,0.485,0,-11.844,1,0.0279,0.0326,0.27,0.157,0.699,177.329,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6736,0LzeivEHO16a8eBQGlpVkE,Love Shack - Edit; 2019 Remaster,53,262587,0,TheBs,gdbcIdNypBsYNuiiCjtN,1989-06-27,0.704,0.828,5,-7.304,0,0.0514,0.11,0.0,0.747,0.866,133.496,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6737,3x6wVKXfCm85Pw7gYo0rqq,That's Amore,53,188267,0,DeanMartinDickStabileAndHisOrchestra,evVmlDcFCMyDvwQliybPPDyupfGWZtsxO,1989-01-01,0.407,0.17,10,-13.409,1,0.0341,0.76,0.0,0.0737,0.577,124.047,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6738,5HeDgLHVXQsp9tYdRpGT5I,Son Mektup,53,287400,0,Zerrinzer,CleFSxMoxkmRduyMwcrm,1989-01-01,0.319,0.566,8,-9.925,1,0.104,0.125,6.48e-06,0.349,0.35,100.275,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6739,2wanmHGKh4DFoOd04Klvuv,Fascination Street - Remastered,53,315187,0,TheCure,buHJOdUbMoVzbos,1989-05-02,0.506,0.909,0,-5.746,0,0.08,0.00145,0.457,0.17,0.499,100.101,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6740,4qz8PpznLcX5AtoUusIiAh,A Girl Like You,53,282867,0,TheSmithereens,KgaEpSluofkcChSoTNr,1989-10-18,0.657,0.828,1,-9.344,1,0.0283,0.0892,0.0,0.0575,0.908,123.799,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6741,2C0JSxStREzKhqthOmP0uo,Qué Voy A Hacer Sin El?,53,203400,0,GloriaTrevi,DbGsIoVWYktPoDnnPZZ,1989-07-05,0.843,0.349,9,-13.043,1,0.102,0.622,6.64e-06,0.113,0.511,105.97,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6742,2zSnnXvex1yMcPUn4mg27H,I Could Write a Book,53,147067,0,HarryConnickJr,uYlWtWoqFFHnUU,1989-07-25,0.453,0.228,0,-13.907,1,0.0444,0.736,1.32e-06,0.193,0.471,127.497,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6743,0uKrQs2xE332mO71m8ujIf,Qué Manera De Perder - Versión Mariachi,53,196213,0,RigoTovar,fKcWhgglQptZaBx,1989-01-01,0.394,0.325,7,-9.612,1,0.0333,0.338,0.0,0.469,0.588,121.911,3
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6744,3o1nX61oecxnqXieA2ma0U,Terrible Lie,53,278867,0,NineInchNails,XXXQSNBYuleKzavUO,1989-10-20,0.61,0.605,6,-12.484,1,0.0419,0.000925,0.157,0.344,0.458,87.953,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6745,6x0cOqPP07gTXusQfK9COQ,La La Love You,53,163640,0,Pixies,zvulxwTWzilBZlBUbT,1989-04-17,0.702,0.653,2,-12.886,1,0.0376,0.00089,0.178,0.11,0.597,124.499,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6746,49wFm43SCnoL2CUxV5BAE2,Noches Eternas - Versión Mariachi,52,165187,0,RigoTovar,fKcWhgglQptZaBx,1989-01-01,0.698,0.457,9,-7.846,1,0.0331,0.249,0.0,0.0672,0.834,113.409,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6747,5EJFGJNumPzY0lPqAe04L8,A Escondidas,52,198893,0,Marisela,cMjCAFNyKYIsnBlqG,1989,0.584,0.314,2,-15.012,1,0.0295,0.681,5.05e-06,0.0486,0.448,68.807,4
# ghgjhh
# Message Type:  <class 'str'>
# Message:  6748,4TDLfAmx45EpSiQYG6hCzT,Dirty Blvd.,52,209267,0,LouReed,TFhlWlMRXiNqzSrnzPL,1989-01-10,0.711,0.412,2,-13.873,1,0.0659,0.308,0.00126,0.0882,0.849,123.35,4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9df87dcc78a3> in <module>()
#      63         print("Message: ", message)
#      64         kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
# ---> 65         time.sleep(1)
#      66
#      67     print("Kafka Producer Application Completed. ")
#
# KeyboardInterrupt:

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler
import random

import time

kafka_topic_name = "songTopic"
kafka_bootstrap_servers = 'localhost:9092'

spark = SparkSession \
        .builder \
        .appName("Spotify Streaming Reccomendation System") \
        .master("local[*]") \
        .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

# Construct a streaming DataFrame that reads from test-topic
songs_df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", kafka_bootstrap_servers) \
        .option("subscribe", kafka_topic_name) \
        .option("startingOffsets", "latest") \
        .load()

songs_df1 = songs_df.selectExpr("CAST(value AS STRING)", "timestamp")


songs_schema_string = "order_id INT,id STRING, name STRING,popularity INT, duration_ms DOUBLE, explicit INT, " \
                           + "artists STRING, id_artists STRING, release_date STRING, " \
                           + "danceability DOUBLE," \
                           + "energy DOUBLE, key INT, loudness DOUBLE, " \
                           + "mode INT," \
                           + "speechiness DOUBLE," \
                           + "acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, " \
                           + "valence DOUBLE, tempo DOUBLE, time_signature DOUBLE"



songs_df2 = songs_df1 \
        .select(from_csv(col("value"), songs_schema_string) \
                .alias("song"), "timestamp")


songs_df3 = songs_df2.select("song.*", "timestamp")

def simple():    
    songs_df3.createOrReplaceTempView("song_find");
    song_find_text = spark.sql("SELECT name, artists FROM song_find")
    songs_agg_write_stream = song_find_text \
            .writeStream \
            .trigger(processingTime='5 seconds') \
            .outputMode("update") \
            .option("truncate", "false") \
            .format("console") \
            .start()

    songs_agg_write_stream.awaitTermination()

    print("Songs Streaming...")
    
def csv_output():    
    song_find_text = spark.sql("SELECT name, artists FROM song_find")
    songs_agg_write_stream = song_find_text \
            .writeStream \
            .trigger(processingTime='5 seconds') \
            .outputMode("append") \
            .option("truncate", "false") \
            .option("path",'answ') \
            .option("checkpointLocation", "checkpoint_path") \
            .format("csv") \
            .start()

    songs_agg_write_stream.awaitTermination()

    print("Songs Streaming...")
    
songs_df3.createOrReplaceTempView("song_find");
song_find_text = spark.sql("SELECT * FROM song_find")
songs_agg_write_stream = song_find_text \
        .writeStream \
        .trigger(processingTime='5 seconds') \
        .outputMode("append") \
        .option("truncate", "false") \
        .format("memory") \
        .queryName("testedTable5") \
        .start()

songs_agg_write_stream.awaitTermination(1)

# %%
# Import libraries
import findspark
findspark.init()
from pyspark.mllib.recommendation import *
import random
from operator import *
from collections import defaultdict

# %%
# Initialize Spark Context
from pyspark import SparkContext, SparkConf
spark = SparkContext.getOrCreate()
spark.stop()
spark = SparkContext('local','Recommender')

# %%
# Import test files from location into RDD variables
artistData = spark.textFile('/content/drive/MyDrive/BigData/artist_data_small.txt').map(lambda s:(int(s.split("\t")[0]),s.split("\t")[1]))
artistAlias = spark.textFile('/content/drive/MyDrive/BigData/artist_alias_small.txt')
userArtistData = spark.textFile('/content/drive/MyDrive/BigData/user_artist_data_small.txt')

# %%
# Split a sequence into seperate entities and store as int

userArtistData = userArtistData.map(lambda s:(int(s.split(" ")[0]),int(s.split(" ")[1]),int(s.split(" ")[2])))

# Create a dictionary of the 'artistAlias' dataset

artistAliasDictionary = {}
dataValue = artistAlias.map(lambda s:(int(s.split("\t")[0]),int(s.split("\t")[1])))
for temp in dataValue.collect():
    artistAliasDictionary[temp[0]] = temp[1]

# If artistid exists, replace with artistsid from artistAlias, else retain original
# YOUR CODE GOES HERE

userArtistData = userArtistData.map(lambda x: (x[0], artistAliasDictionary[x[1]] if x[1] in artistAliasDictionary else x[1], x[2]))

# Create an RDD consisting of 'userid' and 'playcount' objects of original tuple

userSum = userArtistData.map(lambda x:(x[0],x[2]))
playCount1 = userSum.map(lambda x: (x[0],x[1])).reduceByKey(lambda a,b : a+b)
playCount2 = userSum.map(lambda x: (x[0],1)).reduceByKey(lambda a,b:a+b)
playSumAndCount = playCount1.leftOuterJoin(playCount2)


# Count instances by key and store in broadcast variable

playSumAndCount = playSumAndCount.map(lambda x: (x[0],x[1][0],int(x[1][0]/x[1][1])))

# Compute and display users with the highest playcount along with their mean playcount across artists

TopThree = playSumAndCount.top(3,key=lambda x: x[1])
for i in TopThree:
    print('User '+str(i[0])+' has a total play count of '+str(i[1])+' and a mean play count of '+str(i[2])+'.')
# Out:
# User 1059637 has a total play count of 674412 and a mean play count of 1878.
# User 2064012 has a total play count of 548427 and a mean play count of 9455.
# User 2069337 has a total play count of 393515 and a mean play count of 1519.

# %%
# Split the 'userArtistData' dataset into training, validation and test datasets. Store in cache for frequent access
trainData, validationData, testData = userArtistData.randomSplit((0.4,0.4,0.2),seed=13)
trainData.cache()
validationData.cache()
testData.cache()

# Display the first 3 records of each dataset followed by the total count of records for each datasets

print(trainData.take(3))
print(validationData.take(3))
print(testData.take(3))
print(trainData.count())
print(validationData.count())
print(testData.count())
# Out:
# [(1059637, 1000049, 1), (1059637, 1000056, 1), (1059637, 1000114, 2)]
# [(1059637, 1000010, 238), (1059637, 1000062, 11), (1059637, 1000123, 2)]
# [(1059637, 1000094, 1), (1059637, 1000112, 423), (1059637, 1000113, 5)]
# 19761
# 19862
# 9858

# %%
def modelEval(model, dataset):
    
    # All artists in the 'userArtistData' dataset
    AllArtists = spark.parallelize(set(userArtistData.map(lambda x:x[1]).collect()))
    
    
    # Set of all users in the current (Validation/Testing) dataset
    AllUsers = spark.parallelize(set(dataset.map(lambda x:x[0]).collect()))
    
    
    # Create a dictionary of (key, values) for current (Validation/Testing) dataset
    ValidationAndTestingDictionary ={}
    for temp in AllUsers.collect():
        tempFilter = dataset.filter(lambda x:x[0] == temp).collect()
        for item in tempFilter:
            if temp in ValidationAndTestingDictionary:
                ValidationAndTestingDictionary[temp].append(item[1])
            else:
                ValidationAndTestingDictionary[temp] = [item[1]]
                    
    
    # Create a dictionary of (key, values) for training dataset
    TrainingDictionary = {}
    for temp in AllUsers.collect():
        tempFilter = trainData.filter(lambda x:x[0] == temp).collect()
        for item in tempFilter:
            if temp in TrainingDictionary:
                TrainingDictionary[temp].append(item[1])
            else:
                TrainingDictionary[temp] = [item[1]]
        
    
    # For each user, calculate the prediction score i.e. similarity between predicted and actual artists
    PredictionScore = 0.00
    for temp in AllUsers.collect():
        ArtistPrediction =  AllArtists.map(lambda x:(temp,x))
        ModelPrediction = model.predictAll(ArtistPrediction)
        tempFilter = ModelPrediction.filter(lambda x :not x[1] in TrainingDictionary[x[0]])
        topPredictions = tempFilter.top(len(ValidationAndTestingDictionary[temp]),key=lambda x:x[2])
        l=[]
        for i in topPredictions:
            l.append(i[1])
        PredictionScore+=len(set(l).intersection(ValidationAndTestingDictionary[temp]))/len(ValidationAndTestingDictionary[temp])    

        
    # Print average score of the model for all users for the specified rank
    print("The model score for rank "+str(model.rank)+" is ~"+str(PredictionScore/len(ValidationAndTestingDictionary)))

# %%
 rankList = [2,10,20]
 for rank in rankList:
     model = ALS.trainImplicit(trainData, rank , seed=345)
     modelEval(model,validationData)
# Out:
# The model score for rank 2 is ~0.07535599799693796
# The model score for rank 10 is ~0.09765418032407164
# The model score for rank 20 is ~0.08667584027612182

# %%
bestModel = ALS.trainImplicit(trainData, rank=10, seed=345)
modelEval(bestModel, testData)
# Out:
# The model score for rank 10 is ~0.06445912100969664

# %%
# Find the top 5 artists for a particular user and list their names
TopFive = bestModel.recommendProducts(1059637,5)
for item in range(0,5):
    print("Artist "+str(item)+": "+artistData.filter(lambda x:x[0] == TopFive[item][1]).collect()[0][1])
# Out:
# Artist 0: Something Corporate
# Artist 1: My Chemical Romance
# Artist 2: Rage Against the Machine
# Artist 3: blink-182
# Artist 4: Evanescence

# %%
TopFive = bestModel.recommendProducts(2064012,5)
for item in range(0,5):
    print("Artist "+str(item)+": "+artistData.filter(lambda x:x[0] == TopFive[item][1]).collect()[0][1])
# Out:
# Artist 0: Rage Against the Machine
# Artist 1: Franz Ferdinand
# Artist 2: Something Corporate
# Artist 3: Sublime
# Artist 4: U2

# %%
TopFive = bestModel.recommendProducts(2069337,5)
for item in range(0,5):
    print("Artist "+str(item)+": "+artistData.filter(lambda x:x[0] == TopFive[item][1]).collect()[0][1])
# Out:
# Artist 0: Switchfoot
# Artist 1: Alkaline Trio
# Artist 2: Green Day
# Artist 3: My Chemical Romance
# Artist 4: The Offspring
